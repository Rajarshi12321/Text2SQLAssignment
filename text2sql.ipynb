# %% [markdown]
# ## 1. Database Schema and Configuration

# %%
import os
import google.generativeai as genai
from test import execute_query
from config import GOOGLE_API_KEY, DATABASE_SCHEMA

import re
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph, END
from langgraph.prebuilt import ToolExecutor
from langchain.tools import Tool
from langchain.schema import HumanMessage
from typing import TypedDict, Annotated, Sequence, Union
from typing import List, Tuple, Dict, Any

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.schema import SystemMessage, HumanMessage


genai.configure(api_key=GOOGLE_API_KEY)

os.environ["LANGCHAIN_API_KEY"] = "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"
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "text2sql"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"

# %% [markdown]
# ## 2. Core Text-to-SQL Functions

# %%
# Load LLMs
llm_sql_generator = ChatGoogleGenerativeAI(model="gemini-2.0-flash-lite-preview-02-05")
llm_sql_validator = ChatGoogleGenerativeAI(model="gemini-2.0-flash-lite-preview-02-05")
llm_agent = ChatGoogleGenerativeAI(model="gemini-2.0-flash-lite-preview-02-05")

# Extract SQL from the model response
def extract_sql(text):
    match = re.search(r"```sql\s*(.*?)\s*```", text, re.DOTALL)
    return match.group(1) if match else text

# Tool 1: Generate SQL Query
def generate_sql(natural_language_query, DATABASE_SCHEMA=DATABASE_SCHEMA):
    """Agent to generate SQL from a natural language question."""
    prompt = f"""
    Database Schema:
    {DATABASE_SCHEMA}

    **************************
    Answer Repeating the question and evidence, and generating the SQL with a query plan.
    
    <---(Example)--->
    **Question**: How many Thai restaurants can be found in San Pablo Ave, Albany?
    **Evidence**: Thai restaurant refers to food_type = 'thai'; San Pablo Ave Albany refers to street_name
    = 'san pablo ave' AND T1.city = 'albany'
    **Query Plan**:
    ** Preparation Steps:**
    1. Initialize the process: Start preparing to execute the query.
    2. Prepare storage: Set up storage space (registers) to hold temporary results, initializing them to NULL.
    3. Open the location table: Open the location table so we can read from it.
    4. Open the generalinfo table: Open the generalinfo table so we can read from it.
    ** Matching Restaurants:**
    1. Start reading the location table: Move to the first row in the location table.
    2. Check if the street matches: Look at the street_name column of the current row in location. If it's not
    "san pablo ave," skip this row.
    3. Identify the matching row: Store the identifier (row ID) of this location entry.
    4. Find the corresponding row in generalinfo: Use the row ID from location to directly find the matching
    row in generalinfo.
    5. Check if the food type matches: Look at the food_type column in generalinfo. If it's not "thai," skip
    this row.
    6. Check if the city matches: Look at the city column in generalinfo. If it's not "albany," skip this row.
    ** Counting Restaurants:**
    1. Prepare to count this match: If all checks pass, prepare to include this row in the final count.
    2. Count this match: Increment the count for each row that meets all the criteria.
    3. Move to the next row in location: Go back to the location table and move to the next row, repeating
    the process until all rows are checked.
    4. Finalize the count: Once all rows have been checked, finalize the count of matching rows.
    5. Prepare the result: Copy the final count to prepare it for output.
    ** Delivering the Result:**
    1. Output the result: Output the final count, which is the number of restaurants that match all the
    specified criteria.
    2. End the process: Stop the query execution process.
    3. Setup phase: Before starting the actual query execution, the system prepares the specific values it will
    be looking for, like "san pablo ave," "thai," and "albany."
    **Final Optimized SQL Query:**
    SELECT COUNT(T1.id_restaurant) FROM generalinfo AS T1 INNER JOIN location AS T2
    ON T1.id_restaurant = T2.id_restaurant WHERE T1.food_type = 'thai' AND T1.city = 'albany' AND
    T2.street_name = 'san pablo ave' 
    
    Only return the SQL query without ``` backticks, no other text. 
    Ensure the table alias is correctly assigned
    
    ---------------------------------
    Question: {natural_language_query}

    SQL Query: 
    """
    response = llm_sql_generator.invoke([HumanMessage(content=prompt)])
    return extract_sql(response.content)

# Tool 2: Validate and Fix SQL Query for PostgreSQL
def validate_and_fix_sql(sql_query):
    """Agent to validate and correct SQL syntax for PostgreSQL."""
    prompt = f"""
    The following SQL query might have syntax issues. Your task is to analyze it and correct any mistakes 
    so that it works properly in **PostgreSQL**.

    Incorrect SQL:
    {sql_query}

    Return only the corrected SQL query without any explanations or ``` backticks.
    
    Make sure to use "ILIKE" instead of "=" for case insensitive matching. If not asked to be case sensitive

    Corrected SQL Query:
    """
    response = llm_sql_validator.invoke([HumanMessage(content=prompt)])
    return extract_sql(response.content)

# Define state type
class AgentState(TypedDict):
    input: str
    database_schema: str
    sql_query: str
    final_query: str

# Define nodes with updated configuration
def generate_sql_node(state: AgentState) -> AgentState:
    """Generate initial SQL query"""
    try:
        sql_query = generate_sql(
            natural_language_query=state["input"],
            DATABASE_SCHEMA=state["database_schema"]
        )
        state["sql_query"] = sql_query
        return state
    except Exception as e:
        print(f"Error in generate_sql_node: {str(e)}")
        raise

def validate_sql_node(state: AgentState) -> AgentState:
    """Validate and fix SQL query"""
    try:
        final_query = validate_and_fix_sql(state["sql_query"])
        state["final_query"] = final_query
        return state
    except Exception as e:
        print(f"Error in validate_sql_node: {str(e)}")
        raise

# Create workflow
workflow = StateGraph(AgentState)

# Add nodes
workflow.add_node("generate_sql", generate_sql_node)
workflow.add_node("validate_sql", validate_sql_node)

# Add edges
workflow.add_edge("generate_sql", "validate_sql")
workflow.add_edge("validate_sql", END)

# Set entry point
workflow.set_entry_point("generate_sql")

# Compile
agent_executor = workflow.compile()

# Example usage
def process_query(natural_language_query: str):
    try:
        result = agent_executor.invoke({
            "input": natural_language_query,
            "database_schema": DATABASE_SCHEMA,
            "sql_query": "",
            "final_query": ""
        })
        
        print("\nNatural Language Query:", natural_language_query)
        print("\nGenerated SQL:", result["final_query"])
        
        # Execute the query
        query_results = execute_query(result["final_query"].replace("\n", " "))
        print("\nQuery Results:\n", query_results,"\n\n\n")
        
        return result["final_query"], query_results
        
    except Exception as e:
        print(f"Error processing query: {str(e)}")
        return None, None

# Test the processing
# test_query = "Show me the top 5 customers who have rented the most movies"
test_query = "List all actors' first and last names."
sql, results = process_query(test_query)
# Out:
# Natural Language Query: List all actors' first and last names.
#
# Generated SQL: SELECT first_name, last_name FROM actor;
#
# Query Results:
#   first_name  |  last_name
# -------------+--------------
#  PENELOPE    | GUINESS
#  NICK        | WAHLBERG
#  ED          | CHASE
#  JENNIFER    | DAVIS
#  JOHNNY      | LOLLOBRIGIDA
#  BETTE       | NICHOLSON
#  GRACE       | MOSTEL
#  MATTHEW     | JOHANSSON
#  JOE         | SWANK
#  CHRISTIAN   | GABLE
#  ZERO        | CAGE
#  KARL        | BERRY
#  UMA         | WOOD
#  VIVIEN      | BERGEN
#  CUBA        | OLIVIER
#  FRED        | COSTNER
#  HELEN       | VOIGHT
#  DAN         | TORN
#  BOB         | FAWCETT
#  LUCILLE     | TRACY
#  KIRSTEN     | PALTROW
#  ELVIS       | MARX
#  SANDRA      | KILMER
#  CAMERON     | STREEP
#  KEVIN       | BLOOM
#  RIP         | CRAWFORD
#  JULIA       | MCQUEEN
#  WOODY       | HOFFMAN
#  ALEC        | WAYNE
#  SANDRA      | PECK
#  SISSY       | SOBIESKI
#  TIM         | HACKMAN
#  MILLA       | PECK
#  AUDREY      | OLIVIER
#  JUDY        | DEAN
#  BURT        | DUKAKIS
#  VAL         | BOLGER
#  TOM         | MCKELLEN
#  GOLDIE      | BRODY
#  JOHNNY      | CAGE
#  JODIE       | DEGENERES
#  TOM         | MIRANDA
#  KIRK        | JOVOVICH
#  NICK        | STALLONE
#  REESE       | KILMER
#  PARKER      | GOLDBERG
#  JULIA       | BARRYMORE
#  FRANCES     | DAY-LEWIS
#  ANNE        | CRONYN
#  NATALIE     | HOPKINS
#  GARY        | PHOENIX
#  CARMEN      | HUNT
#  MENA        | TEMPLE
#  PENELOPE    | PINKETT
#  FAY         | KILMER
#  DAN         | HARRIS
#  JUDE        | CRUISE
#  CHRISTIAN   | AKROYD
#  DUSTIN      | TAUTOU
#  HENRY       | BERRY
#  CHRISTIAN   | NEESON
#  JAYNE       | NEESON
#  CAMERON     | WRAY
#  RAY         | JOHANSSON
#  ANGELA      | HUDSON
#  MARY        | TANDY
#  JESSICA     | BAILEY
#  RIP         | WINSLET
#  KENNETH     | PALTROW
#  MICHELLE    | MCCONAUGHEY
#  ADAM        | GRANT
#  SEAN        | WILLIAMS
#  GARY        | PENN
#  MILLA       | KEITEL
#  BURT        | POSEY
#  ANGELINA    | ASTAIRE
#  CARY        | MCCONAUGHEY
#  GROUCHO     | SINATRA
#  MAE         | HOFFMAN
#  RALPH       | CRUZ
#  SCARLETT    | DAMON
#  WOODY       | JOLIE
#  BEN         | WILLIS
#  JAMES       | PITT
#  MINNIE      | ZELLWEGER
#  GREG        | CHAPLIN
#  SPENCER     | PECK
#  KENNETH     | PESCI
#  CHARLIZE    | DENCH
#  SEAN        | GUINESS
#  CHRISTOPHER | BERRY
#  KIRSTEN     | AKROYD
#  ELLEN       | PRESLEY
#  KENNETH     | TORN
#  DARYL       | WAHLBERG
#  GENE        | WILLIS
#  MEG         | HAWKE
#  CHRIS       | BRIDGES
#  JIM         | MOSTEL
#  SPENCER     | DEPP
#  SUSAN       | DAVIS
#  WALTER      | TORN
#  MATTHEW     | LEIGH
#  PENELOPE    | CRONYN
#  SIDNEY      | CROWE
#  GROUCHO     | DUNST
#  GINA        | DEGENERES
#  WARREN      | NOLTE
#  SYLVESTER   | DERN
#  SUSAN       | DAVIS
#  CAMERON     | ZELLWEGER
#  RUSSELL     | BACALL
#  MORGAN      | HOPKINS
#  MORGAN      | MCDORMAND
#  HARRISON    | BALE
#  DAN         | STREEP
#  RENEE       | TRACY
#  CUBA        | ALLEN
#  WARREN      | JACKMAN
#  PENELOPE    | MONROE
#  LIZA        | BERGMAN
#  SALMA       | NOLTE
#  JULIANNE    | DENCH
#  SCARLETT    | BENING
#  ALBERT      | NOLTE
#  FRANCES     | TOMEI
#  KEVIN       | GARLAND
#  CATE        | MCQUEEN
#  DARYL       | CRAWFORD
#  GRETA       | KEITEL
#  JANE        | JACKMAN
#  ADAM        | HOPPER
#  RICHARD     | PENN
#  GENE        | HOPKINS
#  RITA        | REYNOLDS
#  ED          | MANSFIELD
#  MORGAN      | WILLIAMS
#  LUCILLE     | DEE
#  EWAN        | GOODING
#  WHOOPI      | HURT
#  CATE        | HARRIS
#  JADA        | RYDER
#  RIVER       | DEAN
#  ANGELA      | WITHERSPOON
#  KIM         | ALLEN
#  ALBERT      | JOHANSSON
#  FAY         | WINSLET
#  EMILY       | DEE
#  RUSSELL     | TEMPLE
#  JAYNE       | NOLTE
#  GEOFFREY    | HESTON
#  BEN         | HARRIS
#  MINNIE      | KILMER
#  MERYL       | GIBSON
#  IAN         | TANDY
#  FAY         | WOOD
#  GRETA       | MALDEN
#  VIVIEN      | BASINGER
#  LAURA       | BRODY
#  CHRIS       | DEPP
#  HARVEY      | HOPE
#  OPRAH       | KILMER
#  CHRISTOPHER | WEST
#  HUMPHREY    | WILLIS
#  AL          | GARLAND
#  NICK        | DEGENERES
#  LAURENCE    | BULLOCK
#  WILL        | WILSON
#  KENNETH     | HOFFMAN
#  MENA        | HOPPER
#  OLYMPIA     | PFEIFFER
#  GROUCHO     | WILLIAMS
#  ALAN        | DREYFUSS
#  MICHAEL     | BENING
#  WILLIAM     | HACKMAN
#  JON         | CHASE
#  GENE        | MCKELLEN
#  LISA        | MONROE
#  ED          | GUINESS
#  JEFF        | SILVERSTONE
#  MATTHEW     | CARREY
#  DEBBIE      | AKROYD
#  RUSSELL     | CLOSE
#  HUMPHREY    | GARLAND
#  MICHAEL     | BOLGER
#  JULIA       | ZELLWEGER
#  RENEE       | BALL
#  ROCK        | DUKAKIS
#  CUBA        | BIRCH
#  AUDREY      | BAILEY
#  GREGORY     | GOODING
#  JOHN        | SUVARI
#  BURT        | TEMPLE
#  MERYL       | ALLEN
#  JAYNE       | SILVERSTONE
#  BELA        | WALKEN
#  REESE       | WEST
#  MARY        | KEITEL
#  JULIA       | FAWCETT
#  THORA       | TEMPLE
# (200 rows)

# %%
import pandas as pd

file_path = r"E:\Assignment projects\Text2Sql-assignment\Pagila Evals Dataset(Sheet1).csv"

# Read CSV with an alternate encoding
test_queries = pd.read_csv(file_path, encoding="ISO-8859-1")  # or encoding="latin1"
print(test_queries.head())
# Out:
#    Query Number                             Natural Language Query Difficulty
# 0             1             List all actors' first and last names.       Easy
# 1             2      Show the titles of all films in the database.       Easy
# 2             3                       Get the names of all cities.       Easy
# 3             4           List all categories available for films.       Easy
# 4             5  Show the first name and last name of all custo...       Easy

# %%
test_queries
# Out:
#     Query Number                             Natural Language Query  \
# 0              1             List all actors' first and last names.
# 1              2      Show the titles of all films in the database.
# 2              3                       Get the names of all cities.
# 3              4           List all categories available for films.
# 4              5  Show the first name and last name of all custo...
# 5              6                   Show all films released in 2006.
# 6              7        Find all actors with the last name "Smith."
# 7              8  List all customers who are from the city of N...
# 8              9     Get all stores located in the country India.
# 9             10  Show all films with a rental rate greater than...
# 10            11         How many films are there in each category?
# 11            12                What is the total number of actors?
# 12            13       Get the total payment received in June 2022.
# 13            14  Find the total number of rentals made last month.
# 14            15           How many films have a rating of PG-13?
# 15            16    List all films along with their category names.
# 16            17  Show all actors who appeared in the film "Ince...
# 17            18  Get a list of all customers and the films they...
# 18            19  List all staff members along with the stores t...
# 19            20      Find all films rented by customer "John Doe."
# 20            21  Show the top 5 films rented the most across al...
# 21            22  List all customers who have rented films in bo...
# 22            23  Find all actors who have appeared in more than...
# 23            24  Get a list of customers who have made more tha...
# 24            25  List all films that are in both the "Action" a...
# 25            26          Show all rentals made in the last 7 days.
# 26            27            Get all payments made in February 2022.
# 27            28  List all films that have not been rented in th...
# 28            29  Find all customers who registered in the last ...
# 29            30  Show all staff members hired before January 1,...
# 30            31  List the top 3 customers who have spent the mo...
# 31            32  Find the films that have been rented more time...
# 32            33  For each actor, show their name and the percen...
# 33            34  Show the average payment amount for each custo...
# 34            35  List all actors who have appeared in at least ...
# 35            36  Find customers who have rented more films this...
# 36            37     List the top 5 films with the highest revenue.
# 37            38  For each customer, show the number of films re...
# 38            39  Show the names of customers who have rented ev...
# 39            40  List customers who have rented the same film m...
#
#    Difficulty                                              Query  \
# 0        Easy             List all actors' first and last names.
# 1        Easy      Show the titles of all films in the database.
# 2        Easy                       Get the names of all cities.
# 3        Easy           List all categories available for films.
# 4        Easy  Show the first name and last name of all custo...
# 5        Easy                   Show all films released in 2006.
# 6        Easy        Find all actors with the last name "Smith."
# 7        Easy  List all customers who are from the city of N...
# 8        Easy     Get all stores located in the country India.
# 9        Easy  Show all films with a rental rate greater than...
# 10     Medium         How many films are there in each category?
# 11     Medium                What is the total number of actors?
# 12     Medium       Get the total payment received in June 2022.
# 13     Medium  Find the total number of rentals made last month.
# 14     Medium           How many films have a rating of PG-13?
# 15     Medium    List all films along with their category names.
# 16     Medium  Show all actors who appeared in the film "Ince...
# 17     Medium  Get a list of all customers and the films they...
# 18     Medium  List all staff members along with the stores t...
# 19     Medium      Find all films rented by customer "John Doe."
# 20     Medium  Show the top 5 films rented the most across al...
# 21     Medium  List all customers who have rented films in bo...
# 22     Medium  Find all actors who have appeared in more than...
# 23     Medium  Get a list of customers who have made more tha...
# 24     Medium  List all films that are in both the "Action" a...
# 25     Medium          Show all rentals made in the last 7 days.
# 26     Medium            Get all payments made in February 2022.
# 27     Medium  List all films that have not been rented in th...
# 28     Medium  Find all customers who registered in the last ...
# 29     Medium  Show all staff members hired before January 1,...
# 30       Hard  List the top 3 customers who have spent the mo...
# 31       Hard  Find the films that have been rented more time...
# 32       Hard  For each actor, show their name and the percen...
# 33       Hard  Show the average payment amount for each custo...
# 34       Hard  List all actors who have appeared in at least ...
# 35       Hard  Find customers who have rented more films this...
# 36       Hard     List the top 5 films with the highest revenue.
# 37       Hard  For each customer, show the number of films re...
# 38       Hard  Show the names of customers who have rented ev...
# 39       Hard  List customers who have rented the same film m...
#
#                                         SQL_Generated  \
# 0            SELECT first_name, last_name FROM actor;
# 1                             SELECT title FROM film;
# 2                              SELECT city FROM city;
# 3                          SELECT name FROM category;
# 4         SELECT first_name, last_name FROM customer;
# 5       SELECT * FROM film WHERE release_year = 2006;
# 6   SELECT actor_id, first_name, last_name\nFROM a...
# 7   SELECT\n  C.first_name,\n  C.last_name\nFROM C...
# 8   SELECT S.store_id\nFROM store AS S\nJOIN addre...
# 9   SELECT film_id, title, rental_rate FROM film W...
# 10  SELECT c.name, COUNT(fc.film_id) AS film_count...
# 11                 SELECT COUNT(actor_id) FROM actor;
# 12  SELECT SUM(amount)\nFROM payment\nWHERE paymen...
# 13  SELECT\n  COUNT(rental_id)\nFROM rental\nWHERE...
# 14  SELECT COUNT(film_id) FROM film WHERE rating =...
# 15  SELECT F.title, C.name\nFROM film AS F\nJOIN f...
# 16  SELECT A.first_name, A.last_name\nFROM actor A...
# 17  SELECT\n  C.first_name,\n  C.last_name,\n  F.t...
# 18  SELECT staff.first_name, staff.last_name, stor...
# 19  SELECT F.title\nFROM film AS F\nJOIN inventory...
# 20  SELECT\n  f.title,\n  COUNT(r.rental_id) AS re...
# 21  SELECT c.first_name, c.last_name\nFROM custome...
# 22  SELECT A.first_name, A.last_name\nFROM actor A...
# 23  SELECT customer_id\nFROM payment\nGROUP BY cus...
# 24  SELECT f.title\nFROM film AS f\nJOIN film_cate...
# 25  SELECT *\nFROM rental\nWHERE rental_date >= NO...
# 26  SELECT *\nFROM payment\nWHERE EXTRACT(MONTH FR...
# 27  SELECT\n  f.title\nFROM film AS f\nLEFT JOIN i...
# 28  SELECT * FROM customer WHERE create_date >= DA...
# 29  SELECT * FROM staff WHERE create_date < '2020-...
# 30  WITH CustomerSpending AS (\n    SELECT\n      ...
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38  SELECT c.first_name, c.last_name\nFROM custome...
# 39  SELECT c.first_name, c.last_name, f.title, COU...
#
#                                               Results
# 0    first_name  |  last_name   \n-------------+--...
# 1               title            \n---------------...
# 2               city            \n----------------...
# 3       name     \n-------------\n Action\n Animat...
# 4    first_name  |  last_name   \n-------------+--...
# 5    film_id |          title          |          ...
# 6    actor_id | first_name | last_name \n---------...
# 7    first_name | last_name \n------------+-------...
# 8    store_id \n----------\n       13\n       18\n...
# 9    film_id |           title           | rental_...
# 10      name     | film_count \n-------------+----...
# 11               count \n-------\n   200\n(1 row)\n\n
# 12        sum    \n----------\n 10923.45\n(1 row)\n\n
# 13               count \n-------\n     0\n(1 row)\n\n
# 14               count \n-------\n   223\n(1 row)\n\n
# 15              title            |    name     \n-...
# 16   first_name | last_name \n------------+-------...
# 17   first_name  |  last_name   |            title...
# 18   first_name  |   last_name   | store_id \n----...
# 19                      title \n-------\n(0 rows)\n\n
# 20          title        | rental_count \n--------...
# 21   first_name  |  last_name   \n-------------+--...
# 22   first_name  |  last_name   \n-------------+--...
# 23   customer_id \n-------------\n         184\n  ...
# 24         title        \n--------------------\n A...
# 25   rental_id | rental_date | inventory_id | cust...
# 26   payment_id | customer_id | staff_id | rental_...
# 27              title            \n---------------...
# 28   customer_id | store_id | first_name | last_na...
# 29  ERROR:  column "create_date" does not exist\nL...
# 30   customer_id |                country         ...
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38   first_name | last_name \n------------+-------...
# 39   first_name | last_name | title | rental_count...

# %%
# test_queries = test_queries[:2]
results = []

for index, row in test_queries.iterrows():
    if pd.isna(row["SQL_Generated"]) or (isinstance(row["SQL_Generated"], str) and "(0 rows)" in row["SQL_Generated"]):
        sql, output = process_query(row["Natural Language Query"])
        print(output, "\n\n\n")

        # Update the DataFrame in place
        test_queries.at[index, "SQL_Generated"] = sql
        test_queries.at[index, "Results"] = output

# Save to CSV after updating all rows
test_queries.to_csv("evaluation_results.csv", index=False)
# Out:
# Natural Language Query: Find the films that have been rented more times than the average number of rentals per film.
#
# Generated SQL: SELECT film_id
# FROM inventory
# GROUP BY film_id
# HAVING COUNT(*) > (
#     SELECT AVG(rental_count)
#     FROM (
#         SELECT COUNT(*) AS rental_count
#         FROM rental
#         JOIN inventory ON rental.inventory_id = inventory.inventory_id
#         GROUP BY inventory.film_id
#     ) AS film_rental_counts
# );
#
# Query Results:
#   film_id
# ---------
# (0 rows)
#
#
#
#
#
#  film_id
# ---------
# (0 rows)
#
#
#
#
#
#
# Natural Language Query: For each actor, show their name and the percentage of films they've acted in compared to the total films.
#
# Generated SQL: SELECT
#   A.first_name,
#   A.last_name,
#   CAST(COUNT(FA.film_id) AS REAL) * 100 / (
#     SELECT
#       COUNT(*)
#     FROM film
#   ) AS percentage_of_films
# FROM actor AS A
# JOIN film_actor AS FA
#   ON A.actor_id = FA.actor_id
# GROUP BY
#   A.actor_id,
#   A.first_name,
#   A.last_name;
#
# Query Results:
#   first_name  |  last_name   | percentage_of_films
# -------------+--------------+---------------------
#  CHRISTIAN   | AKROYD       |                 3.2
#  MATTHEW     | JOHANSSON    |                   2
#  HUMPHREY    | GARLAND      |                 2.9
#  DAN         | STREEP       |                 2.4
#  SPENCER     | PECK         |                 2.1
#  ADAM        | GRANT        |                 1.8
#  RIP         | WINSLET      |                   3
#  GARY        | PHOENIX      |                 2.5
#  ALBERT      | JOHANSSON    |                 3.3
#  RALPH       | CRUZ         |                 2.8
#  MICHELLE    | MCCONAUGHEY  |                 2.3
#  CARMEN      | HUNT         |                 2.6
#  AUDREY      | BAILEY       |                 2.7
#  OPRAH       | KILMER       |                 2.5
#  ADAM        | HOPPER       |                 2.2
#  JAMES       | PITT         |                 3.1
#  MENA        | HOPPER       |                 2.4
#  JOHN        | SUVARI       |                 2.9
#  JON         | CHASE        |                 2.9
#  KENNETH     | HOFFMAN      |                 2.9
#  KIRSTEN     | AKROYD       |                 3.4
#  SUSAN       | DAVIS        |                 3.3
#  KENNETH     | PALTROW      |                 2.1
#  JEFF        | SILVERSTONE  |                 2.5
#  HARRISON    | BALE         |                 2.8
#  MORGAN      | MCDORMAND    |                 2.5
#  HENRY       | BERRY        |                 3.5
#  MEG         | HAWKE        |                 2.7
#  RUSSELL     | BACALL       |                 2.5
#  WARREN      | NOLTE        |                 3.4
#  ELVIS       | MARX         |                 2.6
#  FAY         | WOOD         |                 2.2
#  DUSTIN      | TAUTOU       |                 2.7
#  REESE       | WEST         |                 3.3
#  RITA        | REYNOLDS     |                   2
#  ANGELA      | HUDSON       |                 3.4
#  KEVIN       | GARLAND      |                 3.3
#  SCARLETT    | BENING       |                 2.6
#  CHRIS       | BRIDGES      |                 2.7
#  ALAN        | DREYFUSS     |                 2.7
#  RUSSELL     | TEMPLE       |                 3.1
#  THORA       | TEMPLE       |                   2
#  GARY        | PENN         |                 2.6
#  MATTHEW     | LEIGH        |                   3
#  NICK        | STALLONE     |                   3
#  ZERO        | CAGE         |                 2.5
#  TOM         | MIRANDA      |                 2.7
#  CUBA        | BIRCH        |                 2.4
#  HARVEY      | HOPE         |                 3.2
#  LIZA        | BERGMAN      |                 2.5
#  RENEE       | TRACY        |                 3.3
#  KENNETH     | PESCI        |                   2
#  WOODY       | JOLIE        |                 3.1
#  ROCK        | DUKAKIS      |                   3
#  ALBERT      | NOLTE        |                 3.1
#  WARREN      | JACKMAN      |                 3.2
#  MORGAN      | HOPKINS      |                 2.7
#  JOHNNY      | CAGE         |                 2.9
#  MINNIE      | KILMER       |                   2
#  KIRK        | JOVOVICH     |                 2.6
#  FAY         | WINSLET      |                 3.1
#  JOE         | SWANK        |                 2.5
#  BELA        | WALKEN       |                   3
#  PENELOPE    | MONROE       |                 2.7
#  CUBA        | OLIVIER      |                 2.8
#  MAE         | HOFFMAN      |                 2.8
#  FRANCES     | DAY-LEWIS    |                 2.6
#  RIP         | CRAWFORD     |                 3.3
#  RENEE       | BALL         |                 3.3
#  MINNIE      | ZELLWEGER    |                 3.1
#  SEAN        | WILLIAMS     |                 2.6
#  DARYL       | WAHLBERG     |                 3.1
#  JUDE        | CRUISE       |                   3
#  SCARLETT    | DAMON        |                 3.6
#  CHRISTIAN   | NEESON       |                 2.5
#  BOB         | FAWCETT      |                 2.5
#  CHRIS       | DEPP         |                   2
#  CARY        | MCCONAUGHEY  |                 2.4
#  GROUCHO     | WILLIAMS     |                 2.5
#  SANDRA      | PECK         |                 1.9
#  KIRSTEN     | PALTROW      |                 2.7
#  JANE        | JACKMAN      |                 2.5
#  ED          | CHASE        |                 2.2
#  MARY        | KEITEL       |                   4
#  HELEN       | VOIGHT       |                 3.2
#  VAL         | BOLGER       |                 3.5
#  WOODY       | HOFFMAN      |                 3.1
#  PENELOPE    | CRONYN       |                 3.1
#  JOHNNY      | LOLLOBRIGIDA |                 2.9
#  OLYMPIA     | PFEIFFER     |                 2.8
#  AL          | GARLAND      |                 2.6
#  DAN         | HARRIS       |                 2.8
#  GEOFFREY    | HESTON       |                 2.6
#  CHRISTOPHER | BERRY        |                   2
#  MILLA       | KEITEL       |                 2.8
#  ED          | GUINESS      |                 2.9
#  PENELOPE    | PINKETT      |                 2.5
#  ALEC        | WAYNE        |                 2.9
#  JENNIFER    | DAVIS        |                 2.2
#  LUCILLE     | DEE          |                 2.4
#  AUDREY      | OLIVIER      |                 2.5
#  MATTHEW     | CARREY       |                 3.9
#  GENE        | WILLIS       |                 2.3
#  BEN         | WILLIS       |                 3.3
#  JESSICA     | BAILEY       |                 2.3
#  CAMERON     | WRAY         |                 1.9
#  SEAN        | GUINESS      |                 3.3
#  CHRISTIAN   | GABLE        |                 2.2
#  SIDNEY      | CROWE        |                 3.4
#  JUDY        | DEAN         |                 1.5
#  MICHAEL     | BENING       |                 2.4
#  REESE       | KILMER       |                 3.2
#  GINA        | DEGENERES    |                 4.2
#  BETTE       | NICHOLSON    |                   2
#  GENE        | HOPKINS      |                 2.2
#  GREG        | CHAPLIN      |                 2.7
#  ANGELA      | WITHERSPOON  |                 3.5
#  GOLDIE      | BRODY        |                 2.8
#  WILL        | WILSON       |                 3.1
#  CHRISTOPHER | WEST         |                 2.1
#  ELLEN       | PRESLEY      |                 2.5
#  CHARLIZE    | DENCH        |                 2.4
#  WILLIAM     | HACKMAN      |                 2.7
#  BURT        | DUKAKIS      |                 2.9
#  SISSY       | SOBIESKI     |                 1.8
#  NATALIE     | HOPKINS      |                 3.2
#  WALTER      | TORN         |                 4.1
#  LAURENCE    | BULLOCK      |                 2.6
#  VIVIEN      | BERGEN       |                   3
#  MARY        | TANDY        |                 3.1
#  SYLVESTER   | DERN         |                 2.2
#  VIVIEN      | BASINGER     |                 3.5
#  IAN         | TANDY        |                 3.1
#  UMA         | WOOD         |                 3.5
#  CUBA        | ALLEN        |                 2.5
#  RICHARD     | PENN         |                   3
#  JAYNE       | SILVERSTONE  |                 2.7
#  CAMERON     | ZELLWEGER    |                 3.3
#  NICK        | WAHLBERG     |                 2.5
#  FRED        | COSTNER      |                 2.7
#  JULIA       | FAWCETT      |                 1.5
#  JAYNE       | NEESON       |                 2.9
#  JULIANNE    | DENCH        |                 3.2
#  BURT        | POSEY        |                 2.4
#  CATE        | MCQUEEN      |                   3
#  FRANCES     | TOMEI        |                 2.3
#  MERYL       | ALLEN        |                 2.2
#  NICK        | DEGENERES    |                 2.2
#  JIM         | MOSTEL       |                 2.6
#  JADA        | RYDER        |                 3.1
#  BEN         | HARRIS       |                 2.3
#  JODIE       | DEGENERES    |                 2.9
#  PARKER      | GOLDBERG     |                 2.4
#  GRETA       | MALDEN       |                 3.2
#  MENA        | TEMPLE       |                   3
#  TIM         | HACKMAN      |                 2.3
#  GRACE       | MOSTEL       |                   3
#  RUSSELL     | CLOSE        |                 1.9
#  SPENCER     | DEPP         |                 2.4
#  ED          | MANSFIELD    |                 3.2
#  TOM         | MCKELLEN     |                 2.5
#  JAYNE       | NOLTE        |                 3.4
#  WHOOPI      | HURT         |                 3.2
#  EWAN        | GOODING      |                 3.3
#  BURT        | TEMPLE       |                 2.3
#  KARL        | BERRY        |                 3.1
#  HUMPHREY    | WILLIS       |                 2.6
#  MORGAN      | WILLIAMS     |                 2.7
#  GROUCHO     | SINATRA      |                 2.6
#  CAMERON     | STREEP       |                 2.4
#  GREGORY     | GOODING      |                   3
#  LAURA       | BRODY        |                 2.6
#  KEVIN       | BLOOM        |                 2.1
#  CATE        | HARRIS       |                 2.8
#  SALMA       | NOLTE        |                 2.5
#  KENNETH     | TORN         |                 3.3
#  JULIA       | ZELLWEGER    |                 1.6
#  MERYL       | GIBSON       |                 2.8
#  ANNE        | CRONYN       |                 2.7
#  JULIA       | BARRYMORE    |                 2.4
#  GENE        | MCKELLEN     |                 2.7
#  LUCILLE     | TRACY        |                   3
#  DEBBIE      | AKROYD       |                 2.4
#  MILLA       | PECK         |                 2.4
#  PENELOPE    | GUINESS      |                 1.9
#  ANGELINA    | ASTAIRE      |                 3.1
#  GROUCHO     | DUNST        |                 3.5
#  DAN         | TORN         |                 2.2
#  MICHAEL     | BOLGER       |                   3
#  RAY         | JOHANSSON    |                   3
#  SUSAN       | DAVIS        |                 2.1
#  LISA        | MONROE       |                 2.3
#  KIM         | ALLEN        |                 2.8
#  FAY         | KILMER       |                   2
#  EMILY       | DEE          |                 1.4
#  GRETA       | KEITEL       |                 2.7
#  DARYL       | CRAWFORD     |                   3
#  JULIA       | MCQUEEN      |                 3.3
#  RIVER       | DEAN         |                 3.1
#  SANDRA      | KILMER       |                 3.7
# (200 rows)
#
#
#
#
#
#  first_name  |  last_name   | percentage_of_films
# -------------+--------------+---------------------
#  CHRISTIAN   | AKROYD       |                 3.2
#  MATTHEW     | JOHANSSON    |                   2
#  HUMPHREY    | GARLAND      |                 2.9
#  DAN         | STREEP       |                 2.4
#  SPENCER     | PECK         |                 2.1
#  ADAM        | GRANT        |                 1.8
#  RIP         | WINSLET      |                   3
#  GARY        | PHOENIX      |                 2.5
#  ALBERT      | JOHANSSON    |                 3.3
#  RALPH       | CRUZ         |                 2.8
#  MICHELLE    | MCCONAUGHEY  |                 2.3
#  CARMEN      | HUNT         |                 2.6
#  AUDREY      | BAILEY       |                 2.7
#  OPRAH       | KILMER       |                 2.5
#  ADAM        | HOPPER       |                 2.2
#  JAMES       | PITT         |                 3.1
#  MENA        | HOPPER       |                 2.4
#  JOHN        | SUVARI       |                 2.9
#  JON         | CHASE        |                 2.9
#  KENNETH     | HOFFMAN      |                 2.9
#  KIRSTEN     | AKROYD       |                 3.4
#  SUSAN       | DAVIS        |                 3.3
#  KENNETH     | PALTROW      |                 2.1
#  JEFF        | SILVERSTONE  |                 2.5
#  HARRISON    | BALE         |                 2.8
#  MORGAN      | MCDORMAND    |                 2.5
#  HENRY       | BERRY        |                 3.5
#  MEG         | HAWKE        |                 2.7
#  RUSSELL     | BACALL       |                 2.5
#  WARREN      | NOLTE        |                 3.4
#  ELVIS       | MARX         |                 2.6
#  FAY         | WOOD         |                 2.2
#  DUSTIN      | TAUTOU       |                 2.7
#  REESE       | WEST         |                 3.3
#  RITA        | REYNOLDS     |                   2
#  ANGELA      | HUDSON       |                 3.4
#  KEVIN       | GARLAND      |                 3.3
#  SCARLETT    | BENING       |                 2.6
#  CHRIS       | BRIDGES      |                 2.7
#  ALAN        | DREYFUSS     |                 2.7
#  RUSSELL     | TEMPLE       |                 3.1
#  THORA       | TEMPLE       |                   2
#  GARY        | PENN         |                 2.6
#  MATTHEW     | LEIGH        |                   3
#  NICK        | STALLONE     |                   3
#  ZERO        | CAGE         |                 2.5
#  TOM         | MIRANDA      |                 2.7
#  CUBA        | BIRCH        |                 2.4
#  HARVEY      | HOPE         |                 3.2
#  LIZA        | BERGMAN      |                 2.5
#  RENEE       | TRACY        |                 3.3
#  KENNETH     | PESCI        |                   2
#  WOODY       | JOLIE        |                 3.1
#  ROCK        | DUKAKIS      |                   3
#  ALBERT      | NOLTE        |                 3.1
#  WARREN      | JACKMAN      |                 3.2
#  MORGAN      | HOPKINS      |                 2.7
#  JOHNNY      | CAGE         |                 2.9
#  MINNIE      | KILMER       |                   2
#  KIRK        | JOVOVICH     |                 2.6
#  FAY         | WINSLET      |                 3.1
#  JOE         | SWANK        |                 2.5
#  BELA        | WALKEN       |                   3
#  PENELOPE    | MONROE       |                 2.7
#  CUBA        | OLIVIER      |                 2.8
#  MAE         | HOFFMAN      |                 2.8
#  FRANCES     | DAY-LEWIS    |                 2.6
#  RIP         | CRAWFORD     |                 3.3
#  RENEE       | BALL         |                 3.3
#  MINNIE      | ZELLWEGER    |                 3.1
#  SEAN        | WILLIAMS     |                 2.6
#  DARYL       | WAHLBERG     |                 3.1
#  JUDE        | CRUISE       |                   3
#  SCARLETT    | DAMON        |                 3.6
#  CHRISTIAN   | NEESON       |                 2.5
#  BOB         | FAWCETT      |                 2.5
#  CHRIS       | DEPP         |                   2
#  CARY        | MCCONAUGHEY  |                 2.4
#  GROUCHO     | WILLIAMS     |                 2.5
#  SANDRA      | PECK         |                 1.9
#  KIRSTEN     | PALTROW      |                 2.7
#  JANE        | JACKMAN      |                 2.5
#  ED          | CHASE        |                 2.2
#  MARY        | KEITEL       |                   4
#  HELEN       | VOIGHT       |                 3.2
#  VAL         | BOLGER       |                 3.5
#  WOODY       | HOFFMAN      |                 3.1
#  PENELOPE    | CRONYN       |                 3.1
#  JOHNNY      | LOLLOBRIGIDA |                 2.9
#  OLYMPIA     | PFEIFFER     |                 2.8
#  AL          | GARLAND      |                 2.6
#  DAN         | HARRIS       |                 2.8
#  GEOFFREY    | HESTON       |                 2.6
#  CHRISTOPHER | BERRY        |                   2
#  MILLA       | KEITEL       |                 2.8
#  ED          | GUINESS      |                 2.9
#  PENELOPE    | PINKETT      |                 2.5
#  ALEC        | WAYNE        |                 2.9
#  JENNIFER    | DAVIS        |                 2.2
#  LUCILLE     | DEE          |                 2.4
#  AUDREY      | OLIVIER      |                 2.5
#  MATTHEW     | CARREY       |                 3.9
#  GENE        | WILLIS       |                 2.3
#  BEN         | WILLIS       |                 3.3
#  JESSICA     | BAILEY       |                 2.3
#  CAMERON     | WRAY         |                 1.9
#  SEAN        | GUINESS      |                 3.3
#  CHRISTIAN   | GABLE        |                 2.2
#  SIDNEY      | CROWE        |                 3.4
#  JUDY        | DEAN         |                 1.5
#  MICHAEL     | BENING       |                 2.4
#  REESE       | KILMER       |                 3.2
#  GINA        | DEGENERES    |                 4.2
#  BETTE       | NICHOLSON    |                   2
#  GENE        | HOPKINS      |                 2.2
#  GREG        | CHAPLIN      |                 2.7
#  ANGELA      | WITHERSPOON  |                 3.5
#  GOLDIE      | BRODY        |                 2.8
#  WILL        | WILSON       |                 3.1
#  CHRISTOPHER | WEST         |                 2.1
#  ELLEN       | PRESLEY      |                 2.5
#  CHARLIZE    | DENCH        |                 2.4
#  WILLIAM     | HACKMAN      |                 2.7
#  BURT        | DUKAKIS      |                 2.9
#  SISSY       | SOBIESKI     |                 1.8
#  NATALIE     | HOPKINS      |                 3.2
#  WALTER      | TORN         |                 4.1
#  LAURENCE    | BULLOCK      |                 2.6
#  VIVIEN      | BERGEN       |                   3
#  MARY        | TANDY        |                 3.1
#  SYLVESTER   | DERN         |                 2.2
#  VIVIEN      | BASINGER     |                 3.5
#  IAN         | TANDY        |                 3.1
#  UMA         | WOOD         |                 3.5
#  CUBA        | ALLEN        |                 2.5
#  RICHARD     | PENN         |                   3
#  JAYNE       | SILVERSTONE  |                 2.7
#  CAMERON     | ZELLWEGER    |                 3.3
#  NICK        | WAHLBERG     |                 2.5
#  FRED        | COSTNER      |                 2.7
#  JULIA       | FAWCETT      |                 1.5
#  JAYNE       | NEESON       |                 2.9
#  JULIANNE    | DENCH        |                 3.2
#  BURT        | POSEY        |                 2.4
#  CATE        | MCQUEEN      |                   3
#  FRANCES     | TOMEI        |                 2.3
#  MERYL       | ALLEN        |                 2.2
#  NICK        | DEGENERES    |                 2.2
#  JIM         | MOSTEL       |                 2.6
#  JADA        | RYDER        |                 3.1
#  BEN         | HARRIS       |                 2.3
#  JODIE       | DEGENERES    |                 2.9
#  PARKER      | GOLDBERG     |                 2.4
#  GRETA       | MALDEN       |                 3.2
#  MENA        | TEMPLE       |                   3
#  TIM         | HACKMAN      |                 2.3
#  GRACE       | MOSTEL       |                   3
#  RUSSELL     | CLOSE        |                 1.9
#  SPENCER     | DEPP         |                 2.4
#  ED          | MANSFIELD    |                 3.2
#  TOM         | MCKELLEN     |                 2.5
#  JAYNE       | NOLTE        |                 3.4
#  WHOOPI      | HURT         |                 3.2
#  EWAN        | GOODING      |                 3.3
#  BURT        | TEMPLE       |                 2.3
#  KARL        | BERRY        |                 3.1
#  HUMPHREY    | WILLIS       |                 2.6
#  MORGAN      | WILLIAMS     |                 2.7
#  GROUCHO     | SINATRA      |                 2.6
#  CAMERON     | STREEP       |                 2.4
#  GREGORY     | GOODING      |                   3
#  LAURA       | BRODY        |                 2.6
#  KEVIN       | BLOOM        |                 2.1
#  CATE        | HARRIS       |                 2.8
#  SALMA       | NOLTE        |                 2.5
#  KENNETH     | TORN         |                 3.3
#  JULIA       | ZELLWEGER    |                 1.6
#  MERYL       | GIBSON       |                 2.8
#  ANNE        | CRONYN       |                 2.7
#  JULIA       | BARRYMORE    |                 2.4
#  GENE        | MCKELLEN     |                 2.7
#  LUCILLE     | TRACY        |                   3
#  DEBBIE      | AKROYD       |                 2.4
#  MILLA       | PECK         |                 2.4
#  PENELOPE    | GUINESS      |                 1.9
#  ANGELINA    | ASTAIRE      |                 3.1
#  GROUCHO     | DUNST        |                 3.5
#  DAN         | TORN         |                 2.2
#  MICHAEL     | BOLGER       |                   3
#  RAY         | JOHANSSON    |                   3
#  SUSAN       | DAVIS        |                 2.1
#  LISA        | MONROE       |                 2.3
#  KIM         | ALLEN        |                 2.8
#  FAY         | KILMER       |                   2
#  EMILY       | DEE          |                 1.4
#  GRETA       | KEITEL       |                 2.7
#  DARYL       | CRAWFORD     |                   3
#  JULIA       | MCQUEEN      |                 3.3
#  RIVER       | DEAN         |                 3.1
#  SANDRA      | KILMER       |                 3.7
# (200 rows)
#
#
#
#
#
#
# Natural Language Query: Show the average payment amount for each customer.
#
# Generated SQL: SELECT c.customer_id, AVG(p.amount) AS average_payment_amount
# FROM customer c
# JOIN payment p ON c.customer_id = p.customer_id
# GROUP BY c.customer_id;
#
# Query Results:
#   customer_id | average_payment_amount
# -------------+------------------------
#          184 |     3.9465217391304348
#           87 |     4.8566666666666667
#          477 |     4.9900000000000000
#          273 |     4.5042857142857143
#          550 |     4.9900000000000000
#          394 |     3.8536363636363636
#           51 |     4.2021212121212121
#          272 |     4.9400000000000000
#           70 |     4.4900000000000000
#          190 |     4.1011111111111111
#          350 |     3.2073913043478261
#          539 |     4.1263636363636364
#          554 |     4.6263636363636364
#          278 |     3.4130769230769231
#          406 |     3.8337500000000000
#          424 |     3.6900000000000000
#          176 |     4.6927027027027027
#          576 |     4.1076470588235294
#          309 |     4.7641935483870968
#          292 |     4.3974074074074074
#          509 |     5.0400000000000000
#          271 |     3.8233333333333333
#           22 |     5.1718181818181818
#          156 |     4.0700000000000000
#          417 |     4.4300000000000000
#          556 |     3.9900000000000000
#          475 |     4.3233333333333333
#          529 |     4.0934482758620690
#          282 |     3.8418518518518519
#          390 |     4.6263636363636364
#          173 |     4.1279310344827586
#          269 |     4.3233333333333333
#          261 |     4.1438461538461538
#          502 |     4.0782352941176471
#           42 |     3.9233333333333333
#          189 |     4.2627272727272727
#          117 |     3.7794736842105263
#          161 |     3.7566666666666667
#          257 |     4.0981081081081081
#          125 |     4.2400000000000000
#          113 |     3.9210344827586207
#           40 |     4.1011111111111111
#           43 |     4.1566666666666667
#          587 |     4.1823076923076923
#          120 |     4.4900000000000000
#          578 |     4.3990909090909091
#          440 |     4.0354545454545455
#          385 |     3.9130769230769231
#          371 |     4.2757142857142857
#          492 |     4.1150000000000000
#          544 |     4.4900000000000000
#          365 |     4.5117391304347826
#          157 |     3.6674193548387097
#          413 |     3.6090476190476190
#          308 |     4.2300000000000000
#          100 |     4.2816666666666667
#          183 |     3.3378260869565217
#          313 |     3.9030434782608696
#          150 |     4.2300000000000000
#          140 |     4.6566666666666667
#          248 |     3.3900000000000000
#          421 |     4.4344444444444444
#          137 |     4.9900000000000000
#          208 |     3.5284615384615385
#           24 |     3.8300000000000000
#          392 |     3.9900000000000000
#          191 |     3.7400000000000000
#          429 |     5.0376190476190476
#           25 |     3.9900000000000000
#           94 |     3.7995238095238095
#          122 |     3.9587500000000000
#          141 |     4.0837500000000000
#          218 |     3.7677777777777778
#          570 |     3.8361538461538462
#           49 |     4.6685714285714286
#          434 |     4.7677777777777778
#          211 |     4.4605882352941176
#          580 |     3.6937037037037037
#          530 |     3.3378260869565217
#          536 |     4.7100000000000000
#          465 |     4.1076470588235294
#          449 |     4.9900000000000000
#          520 |     4.2087500000000000
#           64 |     3.0506060606060606
#           55 |     4.5809090909090909
#          148 |     4.7073913043478261
# (599 rows)
#
#
#
#
#
#  customer_id | average_payment_amount
# -------------+------------------------
#          184 |     3.9465217391304348
#           87 |     4.8566666666666667
#          477 |     4.9900000000000000
#          273 |     4.5042857142857143
#          550 |     4.9900000000000000
#          394 |     3.8536363636363636
#           51 |     4.2021212121212121
#          272 |     4.9400000000000000
#           70 |     4.4900000000000000
#          190 |     4.1011111111111111
#          350 |     3.2073913043478261
#          539 |     4.1263636363636364
#          554 |     4.6263636363636364
#          278 |     3.4130769230769231
#          406 |     3.8337500000000000
#          424 |     3.6900000000000000
#          176 |     4.6927027027027027
#          576 |     4.1076470588235294
#          309 |     4.7641935483870968
#          292 |     4.3974074074074074
#          509 |     5.0400000000000000
#          271 |     3.8233333333333333
#           22 |     5.1718181818181818
#          156 |     4.0700000000000000
#          417 |     4.4300000000000000
#          556 |     3.9900000000000000
#          475 |     4.3233333333333333
#          529 |     4.0934482758620690
#          282 |     3.8418518518518519
#          390 |     4.6263636363636364
#          173 |     4.1279310344827586
#          269 |     4.3233333333333333
#          261 |     4.1438461538461538
#          502 |     4.0782352941176471
#           42 |     3.9233333333333333
#          189 |     4.2627272727272727
#          117 |     3.7794736842105263
#          161 |     3.7566666666666667
#          257 |     4.0981081081081081
#          125 |     4.2400000000000000
#          113 |     3.9210344827586207
#           40 |     4.1011111111111111
#           43 |     4.1566666666666667
#          587 |     4.1823076923076923
#          120 |     4.4900000000000000
#          578 |     4.3990909090909091
#          440 |     4.0354545454545455
#          187 |     5.7042857142857143
#          349 |     4.7831034482758621
#           57 |     4.0971428571428571
#           19 |     5.2400000000000000
#          160 |     3.9529629629629630
#          506 |     4.3614285714285714
#          508 |     5.1100000000000000
#          242 |     4.3962500000000000
#          357 |     3.4515384615384615
#          331 |     4.5455555555555556
#          599 |     4.4110526315789474
#          266 |     4.2400000000000000
#          315 |     4.9900000000000000
#          568 |     3.1804761904761905
#          385 |     3.9130769230769231
#          371 |     4.2757142857142857
#          492 |     4.1150000000000000
#          544 |     4.4900000000000000
#          365 |     4.5117391304347826
#          157 |     3.6674193548387097
#          413 |     3.6090476190476190
#          308 |     4.2300000000000000
#          100 |     4.2816666666666667
#          183 |     3.3378260869565217
#          313 |     3.9030434782608696
#          150 |     4.2300000000000000
#          140 |     4.6566666666666667
#          248 |     3.3900000000000000
#          421 |     4.4344444444444444
#          137 |     4.9900000000000000
#          208 |     3.5284615384615385
#           24 |     3.8300000000000000
#          392 |     3.9900000000000000
#          191 |     3.7400000000000000
#          429 |     5.0376190476190476
#           25 |     3.9900000000000000
#           94 |     3.7995238095238095
#          122 |     3.9587500000000000
#          141 |     4.0837500000000000
#          218 |     3.7677777777777778
#          570 |     3.8361538461538462
#           49 |     4.6685714285714286
#          434 |     4.7677777777777778
#          211 |     4.4605882352941176
#          580 |     3.6937037037037037
#          530 |     3.3378260869565217
#          536 |     4.7100000000000000
#          465 |     4.1076470588235294
#          449 |     4.9900000000000000
#          520 |     4.2087500000000000
#           64 |     3.0506060606060606
#           55 |     4.5809090909090909
#          148 |     4.7073913043478261
# (599 rows)
#
#
#
#
#
#
# Natural Language Query: List all actors who have appeared in at least one film in each category.
#
# Generated SQL: SELECT a.first_name, a.last_name
# FROM actor a
# JOIN film_actor fa ON a.actor_id = fa.actor_id
# JOIN film_category fc ON fa.film_id = fc.film_id
# GROUP BY a.actor_id, a.first_name, a.last_name
# HAVING COUNT(DISTINCT fc.category_id) = (SELECT COUNT(*) FROM category);
#
# Query Results:
#   first_name  |  last_name
# -------------+--------------
#  PENELOPE    | GUINESS
#  NICK        | WAHLBERG
#  ED          | CHASE
#  JENNIFER    | DAVIS
#  JOHNNY      | LOLLOBRIGIDA
#  GRACE       | MOSTEL
#  MATTHEW     | JOHANSSON
#  JOE         | SWANK
#  CHRISTIAN   | GABLE
#  ZERO        | CAGE
#  KARL        | BERRY
#  UMA         | WOOD
#  VIVIEN      | BERGEN
#  CUBA        | OLIVIER
#  FRED        | COSTNER
#  HELEN       | VOIGHT
#  DAN         | TORN
#  BOB         | FAWCETT
#  LUCILLE     | TRACY
#  KIRSTEN     | PALTROW
#  ELVIS       | MARX
#  SANDRA      | KILMER
#  CAMERON     | STREEP
#  KEVIN       | BLOOM
#  RIP         | CRAWFORD
#  JULIA       | MCQUEEN
#  WOODY       | HOFFMAN
#  ALEC        | WAYNE
#  SANDRA      | PECK
#  TIM         | HACKMAN
#  MILLA       | PECK
#  AUDREY      | OLIVIER
#  JUDY        | DEAN
#  BURT        | DUKAKIS
#  VAL         | BOLGER
#  TOM         | MCKELLEN
#  GOLDIE      | BRODY
#  JOHNNY      | CAGE
#  JODIE       | DEGENERES
#  TOM         | MIRANDA
#  KIRK        | JOVOVICH
#  REESE       | KILMER
#  PARKER      | GOLDBERG
#  JULIA       | BARRYMORE
#  FRANCES     | DAY-LEWIS
#  ANNE        | CRONYN
#  NATALIE     | HOPKINS
#  GARY        | PHOENIX
#  CARMEN      | HUNT
#  MENA        | TEMPLE
#  FAY         | KILMER
#  DAN         | HARRIS
#  JUDE        | CRUISE
#  CHRISTIAN   | AKROYD
#  DUSTIN      | TAUTOU
#  HENRY       | BERRY
#  CHRISTIAN   | NEESON
#  JAYNE       | NEESON
#  RAY         | JOHANSSON
#  ANGELA      | HUDSON
#  MARY        | TANDY
#  JESSICA     | BAILEY
#  RIP         | WINSLET
#  KENNETH     | PALTROW
#  MICHELLE    | MCCONAUGHEY
#  ADAM        | GRANT
#  SEAN        | WILLIAMS
#  GARY        | PENN
#  BURT        | POSEY
#  ANGELINA    | ASTAIRE
#  CARY        | MCCONAUGHEY
#  GROUCHO     | SINATRA
#  MAE         | HOFFMAN
#  RALPH       | CRUZ
#  SCARLETT    | DAMON
#  WOODY       | JOLIE
#  BEN         | WILLIS
#  JAMES       | PITT
#  MINNIE      | ZELLWEGER
#  GREG        | CHAPLIN
#  SPENCER     | PECK
#  KENNETH     | PESCI
#  CHARLIZE    | DENCH
#  SEAN        | GUINESS
#  CHRISTOPHER | BERRY
#  KIRSTEN     | AKROYD
#  ELLEN       | PRESLEY
#  KENNETH     | TORN
#  DARYL       | WAHLBERG
#  GENE        | WILLIS
#  MEG         | HAWKE
#  CHRIS       | BRIDGES
#  JIM         | MOSTEL
#  SUSAN       | DAVIS
#  WALTER      | TORN
#  MATTHEW     | LEIGH
#  PENELOPE    | CRONYN
#  SIDNEY      | CROWE
#  GROUCHO     | DUNST
#  GINA        | DEGENERES
#  WARREN      | NOLTE
#  SUSAN       | DAVIS
#  CAMERON     | ZELLWEGER
#  RUSSELL     | BACALL
#  MORGAN      | HOPKINS
#  MORGAN      | MCDORMAND
#  HARRISON    | BALE
#  DAN         | STREEP
#  RENEE       | TRACY
#  WARREN      | JACKMAN
#  PENELOPE    | MONROE
#  LIZA        | BERGMAN
#  SALMA       | NOLTE
#  JULIANNE    | DENCH
#  SCARLETT    | BENING
#  ALBERT      | NOLTE
#  FRANCES     | TOMEI
#  KEVIN       | GARLAND
#  CATE        | MCQUEEN
#  DARYL       | CRAWFORD
#  GRETA       | KEITEL
#  JANE        | JACKMAN
#  ADAM        | HOPPER
#  RICHARD     | PENN
#  GENE        | HOPKINS
#  ED          | MANSFIELD
#  MORGAN      | WILLIAMS
#  LUCILLE     | DEE
#  EWAN        | GOODING
#  WHOOPI      | HURT
#  CATE        | HARRIS
#  JADA        | RYDER
#  RIVER       | DEAN
#  ANGELA      | WITHERSPOON
#  KIM         | ALLEN
#  ALBERT      | JOHANSSON
#  FAY         | WINSLET
#  EMILY       | DEE
#  RUSSELL     | TEMPLE
#  JAYNE       | NOLTE
#  GEOFFREY    | HESTON
#  BEN         | HARRIS
#  MINNIE      | KILMER
#  MERYL       | GIBSON
#  IAN         | TANDY
#  FAY         | WOOD
#  GRETA       | MALDEN
#  VIVIEN      | BASINGER
#  LAURA       | BRODY
#  CHRIS       | DEPP
#  HARVEY      | HOPE
#  CHRISTOPHER | WEST
#  HUMPHREY    | WILLIS
#  AL          | GARLAND
#  NICK        | DEGENERES
#  LAURENCE    | BULLOCK
#  WILL        | WILSON
#  KENNETH     | HOFFMAN
#  OLYMPIA     | PFEIFFER
#  GROUCHO     | WILLIAMS
#  ALAN        | DREYFUSS
#  MICHAEL     | BENING
#  WILLIAM     | HACKMAN
#  JON         | CHASE
#  GENE        | MCKELLEN
#  LISA        | MONROE
#  ED          | GUINESS
#  JEFF        | SILVERSTONE
#  MATTHEW     | CARREY
#  DEBBIE      | AKROYD
#  RUSSELL     | CLOSE
#  HUMPHREY    | GARLAND
#  MICHAEL     | BOLGER
#  RENEE       | BALL
#  ROCK        | DUKAKIS
#  CUBA        | BIRCH
#  AUDREY      | BAILEY
#  GREGORY     | GOODING
#  JOHN        | SUVARI
#  BURT        | TEMPLE
#  MERYL       | ALLEN
#  JAYNE       | SILVERSTONE
#  BELA        | WALKEN
#  REESE       | WEST
#  MARY        | KEITEL
# (185 rows)
#
#
#
#
#
#  first_name  |  last_name
# -------------+--------------
#  PENELOPE    | GUINESS
#  NICK        | WAHLBERG
#  ED          | CHASE
#  JENNIFER    | DAVIS
#  JOHNNY      | LOLLOBRIGIDA
#  GRACE       | MOSTEL
#  MATTHEW     | JOHANSSON
#  JOE         | SWANK
#  CHRISTIAN   | GABLE
#  ZERO        | CAGE
#  KARL        | BERRY
#  UMA         | WOOD
#  VIVIEN      | BERGEN
#  CUBA        | OLIVIER
#  FRED        | COSTNER
#  HELEN       | VOIGHT
#  DAN         | TORN
#  BOB         | FAWCETT
#  LUCILLE     | TRACY
#  KIRSTEN     | PALTROW
#  ELVIS       | MARX
#  SANDRA      | KILMER
#  CAMERON     | STREEP
#  KEVIN       | BLOOM
#  RIP         | CRAWFORD
#  JULIA       | MCQUEEN
#  WOODY       | HOFFMAN
#  ALEC        | WAYNE
#  SANDRA      | PECK
#  TIM         | HACKMAN
#  MILLA       | PECK
#  AUDREY      | OLIVIER
#  JUDY        | DEAN
#  BURT        | DUKAKIS
#  VAL         | BOLGER
#  TOM         | MCKELLEN
#  GOLDIE      | BRODY
#  JOHNNY      | CAGE
#  JODIE       | DEGENERES
#  TOM         | MIRANDA
#  KIRK        | JOVOVICH
#  REESE       | KILMER
#  PARKER      | GOLDBERG
#  JULIA       | BARRYMORE
#  FRANCES     | DAY-LEWIS
#  ANNE        | CRONYN
#  NATALIE     | HOPKINS
#  GARY        | PHOENIX
#  CARMEN      | HUNT
#  MENA        | TEMPLE
#  FAY         | KILMER
#  DAN         | HARRIS
#  JUDE        | CRUISE
#  CHRISTIAN   | AKROYD
#  DUSTIN      | TAUTOU
#  HENRY       | BERRY
#  CHRISTIAN   | NEESON
#  JAYNE       | NEESON
#  RAY         | JOHANSSON
#  ANGELA      | HUDSON
#  MARY        | TANDY
#  JESSICA     | BAILEY
#  RIP         | WINSLET
#  KENNETH     | PALTROW
#  MICHELLE    | MCCONAUGHEY
#  ADAM        | GRANT
#  SEAN        | WILLIAMS
#  GARY        | PENN
#  BURT        | POSEY
#  ANGELINA    | ASTAIRE
#  CARY        | MCCONAUGHEY
#  GROUCHO     | SINATRA
#  MAE         | HOFFMAN
#  RALPH       | CRUZ
#  SCARLETT    | DAMON
#  WOODY       | JOLIE
#  BEN         | WILLIS
#  JAMES       | PITT
#  MINNIE      | ZELLWEGER
#  GREG        | CHAPLIN
#  SPENCER     | PECK
#  KENNETH     | PESCI
#  CHARLIZE    | DENCH
#  SEAN        | GUINESS
#  CHRISTOPHER | BERRY
#  KIRSTEN     | AKROYD
#  ELLEN       | PRESLEY
#  KENNETH     | TORN
#  DARYL       | WAHLBERG
#  GENE        | WILLIS
#  MEG         | HAWKE
#  CHRIS       | BRIDGES
#  JIM         | MOSTEL
#  SUSAN       | DAVIS
#  WALTER      | TORN
#  MATTHEW     | LEIGH
#  PENELOPE    | CRONYN
#  SIDNEY      | CROWE
#  GROUCHO     | DUNST
#  GINA        | DEGENERES
#  WARREN      | NOLTE
#  SUSAN       | DAVIS
#  CAMERON     | ZELLWEGER
#  RUSSELL     | BACALL
#  MORGAN      | HOPKINS
#  MORGAN      | MCDORMAND
#  HARRISON    | BALE
#  DAN         | STREEP
#  RENEE       | TRACY
#  WARREN      | JACKMAN
#  PENELOPE    | MONROE
#  LIZA        | BERGMAN
#  SALMA       | NOLTE
#  JULIANNE    | DENCH
#  SCARLETT    | BENING
#  ALBERT      | NOLTE
#  FRANCES     | TOMEI
#  KEVIN       | GARLAND
#  CATE        | MCQUEEN
#  DARYL       | CRAWFORD
#  GRETA       | KEITEL
#  JANE        | JACKMAN
#  ADAM        | HOPPER
#  RICHARD     | PENN
#  GENE        | HOPKINS
#  ED          | MANSFIELD
#  MORGAN      | WILLIAMS
#  LUCILLE     | DEE
#  EWAN        | GOODING
#  WHOOPI      | HURT
#  CATE        | HARRIS
#  JADA        | RYDER
#  RIVER       | DEAN
#  ANGELA      | WITHERSPOON
#  KIM         | ALLEN
#  ALBERT      | JOHANSSON
#  FAY         | WINSLET
#  EMILY       | DEE
#  RUSSELL     | TEMPLE
#  JAYNE       | NOLTE
#  GEOFFREY    | HESTON
#  BEN         | HARRIS
#  MINNIE      | KILMER
#  MERYL       | GIBSON
#  IAN         | TANDY
#  FAY         | WOOD
#  GRETA       | MALDEN
#  VIVIEN      | BASINGER
#  LAURA       | BRODY
#  CHRIS       | DEPP
#  HARVEY      | HOPE
#  CHRISTOPHER | WEST
#  HUMPHREY    | WILLIS
#  AL          | GARLAND
#  NICK        | DEGENERES
#  LAURENCE    | BULLOCK
#  WILL        | WILSON
#  KENNETH     | HOFFMAN
#  OLYMPIA     | PFEIFFER
#  GROUCHO     | WILLIAMS
#  ALAN        | DREYFUSS
#  MICHAEL     | BENING
#  WILLIAM     | HACKMAN
#  JON         | CHASE
#  GENE        | MCKELLEN
#  LISA        | MONROE
#  ED          | GUINESS
#  JEFF        | SILVERSTONE
#  MATTHEW     | CARREY
#  DEBBIE      | AKROYD
#  RUSSELL     | CLOSE
#  HUMPHREY    | GARLAND
#  MICHAEL     | BOLGER
#  RENEE       | BALL
#  ROCK        | DUKAKIS
#  CUBA        | BIRCH
#  AUDREY      | BAILEY
#  GREGORY     | GOODING
#  JOHN        | SUVARI
#  BURT        | TEMPLE
#  MERYL       | ALLEN
#  JAYNE       | SILVERSTONE
#  BELA        | WALKEN
#  REESE       | WEST
#  MARY        | KEITEL
# (185 rows)
#
#
#
#
#
#
# Natural Language Query: Find customers who have rented more films this year than last year.
#
# Generated SQL: SELECT c.first_name, c.last_name
# FROM customer c
# JOIN rental r ON c.customer_id = r.customer_id
# WHERE EXTRACT(YEAR FROM r.rental_date) = EXTRACT(YEAR FROM CURRENT_DATE)
# GROUP BY c.customer_id, c.first_name, c.last_name
# HAVING COUNT(DISTINCT r.rental_id) > (
#     SELECT COUNT(DISTINCT r2.rental_id)
#     FROM rental r2
#     WHERE r2.customer_id = c.customer_id
#       AND EXTRACT(YEAR FROM r2.rental_date) = EXTRACT(YEAR FROM CURRENT_DATE) - 1
# );
#
# Query Results:
#   first_name | last_name
# ------------+-----------
# (0 rows)
#
#
#
#
#
#  first_name | last_name
# ------------+-----------
# (0 rows)
#
#
#
#
#
#
# Natural Language Query: List the top 5 films with the highest revenue.
#
# Generated SQL: SELECT
#   F.title,
#   SUM(P.amount) AS total_revenue
# FROM film AS F
# JOIN inventory AS I
#   ON F.film_id = I.film_id
# JOIN rental AS R
#   ON I.inventory_id = R.inventory_id
# JOIN payment AS P
#   ON R.rental_id = P.rental_id
# GROUP BY
#   F.film_id,
#   F.title
# ORDER BY
#   total_revenue DESC
# LIMIT 5;
#
# Query Results:
#         title       | total_revenue
# -------------------+---------------
#  TELEGRAPH VOYAGE  |        231.73
#  WIFE TURN         |        223.69
#  ZORRO ARK         |        214.69
#  GOODFELLAS SALUTE |        209.69
#  SATURDAY LAMBS    |        204.72
# (5 rows)
#
#
#
#
#
#        title       | total_revenue
# -------------------+---------------
#  TELEGRAPH VOYAGE  |        231.73
#  WIFE TURN         |        223.69
#  ZORRO ARK         |        214.69
#  GOODFELLAS SALUTE |        209.69
#  SATURDAY LAMBS    |        204.72
# (5 rows)
#
#
#
#
#
#
# Natural Language Query: For each customer, show the number of films rented in the last month compared to the previous month.
#
# Generated SQL: WITH MonthlyRentals AS (
#     SELECT
#         c.customer_id,
#         DATE_TRUNC('month', r.rental_date) AS rental_month,
#         COUNT(r.rental_id) AS rental_count
#     FROM
#         customer c
#     JOIN
#         rental r ON c.customer_id = r.customer_id
#     WHERE
#         r.rental_date >= DATE_TRUNC('month', NOW() - INTERVAL '2 months')
#     GROUP BY
#         c.customer_id,
#         DATE_TRUNC('month', r.rental_date)
# ),
# LaggedRentals AS (
#     SELECT
#         customer_id,
#         rental_month,
#         rental_count,
#         LAG(rental_count, 1, 0) OVER (PARTITION BY customer_id ORDER BY rental_month) AS previous_month_rental_count
#     FROM
#         MonthlyRentals
# )
# SELECT
#     customer_id,
#     rental_month,
#     rental_count,
#     previous_month_rental_count,
#     rental_count - previous_month_rental_count AS rental_difference
# FROM
#     LaggedRentals
# ORDER BY
#     customer_id,
#     rental_month;
#
# Query Results:
#   customer_id | rental_month | rental_count | previous_month_rental_count | rental_difference
# -------------+--------------+--------------+-----------------------------+-------------------
# (0 rows)
#
#
#
#
#
#  customer_id | rental_month | rental_count | previous_month_rental_count | rental_difference
# -------------+--------------+--------------+-----------------------------+-------------------
# (0 rows)

# %%
import pandas as pd

file_path = r"E:\Assignment projects\Text2Sql-assignment\evaluation_results.csv"

# Read CSV with an alternate encoding
evaluated_df = pd.read_csv(file_path, encoding="ISO-8859-1")  # or encoding="latin1"
print(evaluated_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Query Number            40 non-null     int64
#  1   Natural Language Query  40 non-null     object
#  2   Difficulty              40 non-null     object
#  3   Query                   40 non-null     object
#  4   SQL_Generated           40 non-null     object
#  5   Results                 40 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.0+ KB
# None

# %%
evaluated_df["Results"]
# Out:
# 0      first_name  |  last_name   \n-------------+--...
# 1                 title            \n---------------...
# 2                 city            \n----------------...
# 3         name     \n-------------\n Action\n Animat...
# 4      first_name  |  last_name   \n-------------+--...
# 5      film_id |          title          |          ...
# 6      actor_id | first_name | last_name \n---------...
# 7      first_name | last_name \n------------+-------...
# 8      store_id \n----------\n       13\n       18\n...
# 9      film_id |           title           | rental_...
# 10        name     | film_count \n-------------+----...
# 11                 count \n-------\n   200\n(1 row)\n\n
# 12          sum    \n----------\n 10923.45\n(1 row)\n\n
# 13                 count \n-------\n     0\n(1 row)\n\n
# 14                 count \n-------\n   223\n(1 row)\n\n
# 15                title            |    name     \n-...
# 16     first_name | last_name \n------------+-------...
# 17     first_name  |  last_name   |            title...
# 18     first_name  |   last_name   | store_id \n----...
# 19                        title \n-------\n(0 rows)\n\n
# 20            title        | rental_count \n--------...
# 21     first_name  |  last_name   \n-------------+--...
# 22     first_name  |  last_name   \n-------------+--...
# 23     customer_id \n-------------\n         184\n  ...
# 24           title        \n--------------------\n A...
# 25     rental_id | rental_date | inventory_id | cust...
# 26     payment_id | customer_id | staff_id | rental_...
# 27                title            \n---------------...
# 28     customer_id | store_id | first_name | last_na...
# 29    ERROR:  column "create_date" does not exist\nL...
# 30     customer_id |                country         ...
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38     first_name | last_name \n------------+-------...
# 39     first_name | last_name | title | rental_count...
# Name: Results, dtype: object

# %%
check = evaluated_df.loc[28,"Results"]

print(check)
# Out:
#  customer_id | store_id | first_name | last_name | email | address_id | activebool | create_date | last_update | active
# -------------+----------+------------+-----------+-------+------------+------------+-------------+-------------+--------
# (0 rows)

# %%
filtered_df = evaluated_df[evaluated_df["Results"].str.contains(r"\(0 rows\)", regex=True, na=False)]
# filtered_df = evaluated_df[evaluated_df["Results"].isna()]
filtered_df
# Out:
#     Query Number                             Natural Language Query  \
# 6              7        Find all actors with the last name "Smith."
# 7              8  List all customers who are from the city of Â...
# 16            17  Show all actors who appeared in the film "Ince...
# 19            20      Find all films rented by customer "John Doe."
# 25            26          Show all rentals made in the last 7 days.
# 28            29  Find all customers who registered in the last ...
# 31            32  Find the films that have been rented more time...
# 35            36  Find customers who have rented more films this...
# 37            38  For each customer, show the number of films re...
# 38            39  Show the names of customers who have rented ev...
# 39            40  List customers who have rented the same film m...
#
#    Difficulty                                              Query  \
# 6        Easy        Find all actors with the last name "Smith."
# 7        Easy  List all customers who are from the city of Â...
# 16     Medium  Show all actors who appeared in the film "Ince...
# 19     Medium      Find all films rented by customer "John Doe."
# 25     Medium          Show all rentals made in the last 7 days.
# 28     Medium  Find all customers who registered in the last ...
# 31       Hard  Find the films that have been rented more time...
# 35       Hard  Find customers who have rented more films this...
# 37       Hard  For each customer, show the number of films re...
# 38       Hard  Show the names of customers who have rented ev...
# 39       Hard  List customers who have rented the same film m...
#
#                                         SQL_Generated  \
# 6   SELECT actor_id, first_name, last_name\nFROM a...
# 7   SELECT\n  C.first_name,\n  C.last_name\nFROM C...
# 16  SELECT A.first_name, A.last_name\nFROM actor A...
# 19  SELECT F.title\nFROM film AS F\nJOIN inventory...
# 25  SELECT *\nFROM rental\nWHERE rental_date >= NO...
# 28  SELECT * FROM customer WHERE create_date >= DA...
# 31  SELECT film_id\nFROM inventory\nGROUP BY film_...
# 35  SELECT c.first_name, c.last_name\nFROM custome...
# 37  WITH MonthlyRentals AS (\n    SELECT\n        ...
# 38  SELECT c.first_name, c.last_name\nFROM custome...
# 39  SELECT c.first_name, c.last_name, f.title, COU...
#
#                                               Results
# 6    actor_id | first_name | last_name \n---------...
# 7    first_name | last_name \n------------+-------...
# 16   first_name | last_name \n------------+-------...
# 19                      title \n-------\n(0 rows)\n\n
# 25   rental_id | rental_date | inventory_id | cust...
# 28   customer_id | store_id | first_name | last_na...
# 31                  film_id \n---------\n(0 rows)\n\n
# 35   first_name | last_name \n------------+-------...
# 37   customer_id | rental_month | rental_count | p...
# 38   first_name | last_name \n------------+-------...
# 39   first_name | last_name | title | rental_count...

# %%
idx=7

query = filtered_df.iloc[idx]["Query"]
sql_query = filtered_df.iloc[idx]["SQL_Generated"]
print("Query:", query)
print("SQL:", sql_query, "\n\n\n")


result = execute_query(sql_query.replace("\n", " "))
print(result)
# Out:
# Query: Find customers who have rented more films this year than last year.
# SQL: SELECT c.first_name, c.last_name
# FROM customer c
# JOIN rental r ON c.customer_id = r.customer_id
# WHERE EXTRACT(YEAR FROM r.rental_date) = EXTRACT(YEAR FROM CURRENT_DATE)
# GROUP BY c.customer_id, c.first_name, c.last_name
# HAVING COUNT(DISTINCT r.rental_id) > (
#     SELECT COUNT(DISTINCT r2.rental_id)
#     FROM rental r2
#     WHERE r2.customer_id = c.customer_id
#       AND EXTRACT(YEAR FROM r2.rental_date) = EXTRACT(YEAR FROM CURRENT_DATE) - 1
# );
#  first_name | last_name
# ------------+-----------
# (0 rows)

# %%
print(execute_query("""SELECT actor_id, first_name, last_name FROM actor WHERE last_name = 'Paltrow'"""))
# Out:
#  actor_id | first_name | last_name
# ----------+------------+-----------
# (0 rows)
