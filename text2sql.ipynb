# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 1. Database Schema and Configuration

# %%
import os
import google.generativeai as genai
from setup_db import execute_query
from config import GOOGLE_API_KEY, DATABASE_SCHEMA,COT_TEXT2SQL_EXAMPLE, LANGCHAIN_API_KEY


import json
import re
import time
import re
import pandas as pd
from tqdm import tqdm
import numpy as np

from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph, END
from langgraph.prebuilt import ToolExecutor
from langchain.tools import Tool
from langchain.schema import HumanMessage
from typing import TypedDict, Annotated, Sequence, Union
from typing import List, Tuple, Dict, Any

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.schema import SystemMessage, HumanMessage


genai.configure(api_key=GOOGLE_API_KEY)

os.environ["LANGCHAIN_API_KEY"] = LANGCHAIN_API_KEY
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "text2sql"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"

# %% [markdown]
# ## 2. Core Text-to-SQL Functions

# %%
# Load LLMs
llm_sql_generator = ChatGoogleGenerativeAI(model="gemini-2.0-flash-lite-preview-02-05")
llm_sql_validator = ChatGoogleGenerativeAI(model="gemini-2.0-flash-lite-preview-02-05")

# Extract SQL from the model response
def extract_sql(text):
    match = re.search(r"```sql\s*(.*?)\s*```", text, re.DOTALL)
    return match.group(1) if match else text

# Tool 1: Generate SQL Query
def generate_sql(natural_language_query, DATABASE_SCHEMA=DATABASE_SCHEMA,COT_TEXT2SQL_EXAMPLE=COT_TEXT2SQL_EXAMPLE):
    """Agent to generate SQL from a natural language question."""
    prompt = f"""
    Properly use the Database Schema to properly use the table names and column names for respective tables.
    
    Database Schema:
    {DATABASE_SCHEMA}

    **************************
    Properly use the Database Schema to generate the SQL query.
    Answer Repeating the question and evidence, and generating the SQL with a query plan.
    
    <---(Example)--->
    {COT_TEXT2SQL_EXAMPLE}
    
    Only return the SQL query without ``` backticks, no other text. 
    Ensure the table alias is correctly assigned
    
    
    ---------------------------------
    Question: {natural_language_query}

    SQL Query: 
    """
    response = llm_sql_generator.invoke([HumanMessage(content=prompt)])
    return extract_sql(response.content)

# Tool 2: Validate and Fix SQL Query for PostgreSQL
def validate_and_fix_sql(sql_query,DATABASE_SCHEMA=DATABASE_SCHEMA):
    """Agent to validate and correct SQL syntax for PostgreSQL."""
    prompt = f"""
    The following SQL query might have syntax issues. Your task is to analyze it and correct any mistakes 
    so that it works properly in **PostgreSQL**.
    
    Properly use the Database Schema to generate the SQL query.
    Database Schema:
    {DATABASE_SCHEMA}

    Incorrect SQL:
    {sql_query}

    Return only the corrected SQL query without any explanations or ``` backticks.
    
    Make sure to use "ILIKE" instead of "=" for case insensitive matching. If not asked to be case sensitive
    Only while using "ILIKE" make sure to use "::TEXT" to avoid type mismatch errors.
    Don't use "::TEXT" while using "=" or anyother time
    

    Corrected SQL Query:
    """
    response = llm_sql_validator.invoke([HumanMessage(content=prompt)])
    return extract_sql(response.content)

# Define state type
class AgentState(TypedDict):
    input: str
    sql_query: str
    final_query: str
    query_results: str  # Add this field

# Define nodes with updated configuration
def generate_sql_node(state: AgentState) -> AgentState:
    """Generate initial SQL query"""
    try:
        sql_query = generate_sql(
            natural_language_query=state["input"],
            DATABASE_SCHEMA=DATABASE_SCHEMA,
            COT_TEXT2SQL_EXAMPLE=COT_TEXT2SQL_EXAMPLE
        )
        state["sql_query"] = sql_query
        return state
    except Exception as e:
        print(f"Error in generate_sql_node: {str(e)}")
        raise

def validate_sql_node(state: AgentState) -> AgentState:
    """Validate and fix SQL query"""
    try:
        final_query = validate_and_fix_sql(state["sql_query"])
        state["final_query"] = final_query
        return state
    except Exception as e:
        print(f"Error in validate_sql_node: {str(e)}")
        raise

def execute_sql_node(state: AgentState) -> AgentState:
    """Execute the SQL query and store results"""
    try:
        query_results = execute_query(state["final_query"].replace("\n", " "))
        state["query_results"] = query_results
        return state
    except Exception as e:
        print(f"Error in execute_sql_node: {str(e)}")
        raise

# Create workflow
workflow = StateGraph(AgentState)

# Add nodes
workflow.add_node("generate_sql", generate_sql_node)
workflow.add_node("validate_sql", validate_sql_node)
workflow.add_node("execute_sql", execute_sql_node)  # Add new node

# Add edges
workflow.add_edge("generate_sql", "validate_sql")
workflow.add_edge("validate_sql", "execute_sql")  # Add edge to new node 
workflow.add_edge("execute_sql", END)  # Update final edge

# Set entry point
workflow.set_entry_point("generate_sql")

# Compile
agent_executor = workflow.compile()

# Update example usage
def process_query(natural_language_query: str, max_retries=5, show_print=False):
    attempt = 0
    error_message = ""

    state = {
        "input": natural_language_query,
        "sql_query": "",
        "final_query": "",
        "query_results": ""
    }

    error_messages = []
    while attempt < max_retries:
        # print(f"Attempt {attempt + 1}:{error_messages}")
        try:
            result = agent_executor.invoke(state)

            # Extract query and results
            sql_query = result["final_query"]
            query_results = result["query_results"]

            if show_print:
                print(f"\nAttempt {attempt + 1}:")
                print("\nNatural Language Query:\n", state["input"])
                print("\nGenerated SQL:\n", sql_query)
                print("\nQuery results:\n", query_results)

            # Check if the result contains an error
            if "ERROR" in query_results.upper():
                # Extract the error message
                error_message = query_results  # Full error message
                error_messages.append(error_message)
                # Prepare the retry prompt
                state["input"] = f"""{natural_language_query}\n\nPrevious Error list: {error_messages}"""
                attempt += 1
                continue  # Retry the process

            # If no error, return the successful result
            return sql_query, query_results

        except Exception as e:
            # print(f"Unexpected error in attempt {attempt + 1}: {str(e)}")
            attempt += 1

    print(f"\nMax retries reached. Last error: {error_message}")
    return None, None  # Return None if max retries are exceeded


# Test the processing
test_query = "Show me the top 5 customers who have rented the most movies"
# test_query = "Show all staff members hired before January 1, 2020."
# test_query = "Show all staff members hired before January 1, 2020., create_date is not in staff table"
sql, results = process_query(test_query,show_print=True)
# Out:
# Attempt 1:
#
# Natural Language Query:
#  Show me the top 5 customers who have rented the most movies
#
# Generated SQL:
#  SELECT
#     C.first_name,
#     C.last_name,
#     COUNT(R.rental_id) AS rental_count
# FROM
#     customer AS C
#     JOIN rental AS R ON C.customer_id = R.customer_id
# GROUP BY
#     C.customer_id,
#     C.first_name,
#     C.last_name
# ORDER BY
#     rental_count DESC
# LIMIT 5;
#
# Query results:
#   first_name | last_name | rental_count
# ------------+-----------+--------------
#  ELEANOR    | HUNT      |           46
#  KARL       | SEAL      |           45
#  MARCIA     | DEAN      |           42
#  CLARA      | SHAW      |           42
#  TAMMY      | SANDERS   |           41
# (5 rows)

# %% [markdown]
# #### Will be used in Gradio App

# %%
llm_query_validator = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash-lite-preview-02-05"
)

def string_to_dict(text):
    """
    Converts a JSON-like structured string into a dictionary, handling extra formatting.

    Args:
        text (str): Input string containing key-value pairs.

    Returns:
        dict: Dictionary with extracted key-value pairs.
    """
        
    # Remove code block markers like ```python and ```
    cleaned_text = re.sub(r"```[\w]*", "", text).strip()

    # Remove trailing commas before closing braces
    cleaned_text = re.sub(r",\s*}", "}", cleaned_text)

    # Convert to dictionary
    data_dict = json.loads(cleaned_text)

    try:
        return json.loads(cleaned_text)
    except json.JSONDecodeError:
        raise ValueError("Invalid JSON format")


# Validate Natural Language Query
def validate_nl_query(natural_language_query, user_instructions=None):
    """Agent to validate and improve natural language query."""
    prompt = f"""
    
    "JUST OUTPUT THE Python DICTIONARY of texts of natural language query"
    You are a helpful assistant that validates natural language queries for a Database.
    Your task is to analyze the query for ambiguity, incompleteness, or incorrectness and improve it if needed.
    You are also allowed to use the database schema to improve the query.

    User Instructions:
    {user_instructions}

    Database Schema:
    {DATABASE_SCHEMA}
    
    Natural Language Query:
    {natural_language_query}
    
    If the query is clear and complete, return it unchanged.
    If the query needs improvement, provide the improved version and explain why.
    Make sure to return the corrected input, the improved query and the feedback.
    Make sure to not alter the original query too much, if there is no typo or discrepancy with database schema. 
    
    
    In the following Format - For example:
    original_query: show moveis with actr smith
    corrected_input: show movies with actor smith
    feedback: Fixed typos in 'movies' and 'actor', added specificity about searching by last name
    
    original_query: show all movies with rating R
    corrected_input: show all movies with rating R
    feedback: Query is clear and well-formed, minor rewording for consistency
    
    original_query: list customer payments
    corrected_input: list customer payments
    feedback: Query is clear and grammatically correct   
    
    Output Format (make sure say why we changed what, if changed): 
    ```python
    {{
        original_query: show moveis with actr smith
        corrected_input: show movies with actor smith
        feedback: Fixed typos in 'movies' and 'actor'
    }}
    ```
    

    """
    response = llm_query_validator.invoke([HumanMessage(content=prompt)])

    print(response.content)
    return string_to_dict(response.content)

# %%
validate_nl_query("Find the films that have been rented more times than the average")
# Out:
# ```python
# {
#     "original_query": "Find the films that have been rented more times than the average",
#     "corrected_input": "Find the films that have been rented more times than the average",
#     "feedback": "The query is clear and grammatically correct"
# }
# ```
# {'original_query': 'Find the films that have been rented more times than the average',
#  'corrected_input': 'Find the films that have been rented more times than the average',
#  'feedback': 'The query is clear and grammatically correct'}

# %%
process_query("Find the films that have been rented more times than the average")
# Out:
# ('SELECT\n  f.title\nFROM film AS f\nJOIN inventory AS i\n  ON f.film_id = i.film_id\nJOIN rental AS r\n  ON i.inventory_id = r.inventory_id\nGROUP BY\n  f.film_id,\n  f.title\nHAVING\n  COUNT(r.rental_id) > (\n    SELECT\n      AVG(rental_count)\n    FROM (\n      SELECT\n        COUNT(r2.rental_id) AS rental_count\n      FROM inventory AS i2\n      JOIN rental AS r2\n        ON i2.inventory_id = r2.inventory_id\n      GROUP BY\n        i2.film_id\n    ) AS film_rental_counts\n  );',
#  '            title            \n-----------------------------\n EFFECT GLADIATOR\n BALLOON HOMEWARD\n VOYAGE LEGALLY\n BIKINI BORROWERS\n GARDEN ISLAND\n CONGENIALITY QUEST\n EXCITEMENT EVE\n PATIENT SISTER\n AMISTAD MIDSUMMER\n EASY GLADIATOR\n HILLS NEIGHBORS\n MALTESE HOPE\n SATURDAY LAMBS\n OPERATION OPERATION\n SEATTLE EXPECATIONS\n SHOW LORD\n MILLION ACE\n BASIC EASY\n AMADEUS HOLY\n CLUB GRAFFITI\n OSCAR GOLD\n DYNAMITE TARZAN\n FELLOWSHIP AUTUMN\n GOLDFINGER SENSIBILITY\n STAR OPERATION\n BOUND CHEAPER\n SLACKER LIAISONS\n FATAL HAUNTED\n BANGER PINOCCHIO\n CONTACT ANONYMOUS\n ROOM ROMAN\n ALADDIN CALENDAR\n ARACHNOPHOBIA ROLLERCOASTER\n DEER VIRGINIAN\n SOUTH WAIT\n CONFUSED CANDLES\n MOONSHINE CABIN\n ENGLISH BULWORTH\n HALF OUTFIELD\n FURY MURDER\n TRAMP OTHERS\n ROSES TREASURE\n LOUISIANA HARRY\n HOMICIDE PEACH\n OPEN AFRICAN\n ROXANNE REBEL\n DESERT POSEIDON\n SECRETARY ROUGE\n COAST RAINBOW\n UNDEFEATED DALMATIONS\n KISSING DOLLS\n MADNESS ATTACKS\n ALTER VICTORY\n CHILL LUCK\n MASSACRE USUAL\n KICK SAVANNAH\n BEACH HEARTBREAKERS\n DETECTIVE VISION\n PEAK FOREVER\n SNATCH SLIPPER\n EXPECATIONS NATURAL\n STORY SIDE\n JEKYLL FROGMEN\n OTHERS SOUP\n GRIT CLOCKWORK\n GREATEST NORTH\n JERICHO MULAN\n OUTBREAK DIVINE\n FLAMINGOS CONNECTICUT\n CAMPUS REMEMBER\n BRIDE INTRIGUE\n BEAR GRACELAND\n CAT CONEHEADS\n MALLRATS UNITED\n FORREST SONS\n SNOWMAN ROLLERCOASTER\n PHILADELPHIA WIFE\n SECRETS PARADISE\n VIRGIN DAISY\n MAIDEN HOME\n VIRGINIAN PLUTO\n BREAKFAST GOLDFINGER\n VOICE PEACH\n CONEHEADS SMOOCHY\n HEARTBREAKERS BRIGHT\n LIES TREATMENT\n FLINTSTONES HAPPINESS\n VANISHING ROCKY\n WOLVES DESIRE\n DRACULA CRYSTAL\n DRIVING POLISH\n CHARIOTS CONSPIRACY\n HOBBIT ALIEN\n WHISPERER GIANT\n BOULEVARD MOB\n HURRICANE AFFAIR\n GUN BONNIE\n ARMAGEDDON LOST\n POND SEATTLE\n LION UNCUT\n KARATE MOON\n CANYON STOCK\n PITY BOUND\n FIREBALL PHILADELPHIA\n MURDER ANTITRUST\n PULP BEVERLY\n JOON NORTHWEST\n INSTINCT AIRPORT\n BRINGING HYSTERICAL\n JASON TRAP\n GRAFFITI LOVE\n GHOST GROUNDHOG\n OUTFIELD MASSACRE\n ALASKA PHANTOM\n JEDI BENEATH\n CLASH FREDDY\n PARADISE SABRINA\n DISTURBING SCARFACE\n JADE BUNCH\n RUGRATS SHAKESPEARE\n EARTH VISION\n TOURIST PELICAN\n CANDIDATE PERDITION\n WESTWARD SEABISCUIT\n TRIP NEWTON\n INSIDER ARIZONA\n JUMPING WRATH\n ROAD ROXANNE\n HOURS RAGE\n WEEKEND PERSONAL\n SWARM GOLD\n NOON PAPI\n DURHAM PANKY\n SCARFACE BANG\n STAGECOACH ARMAGEDDON\n CHRISTMAS MOONSHINE\n EMPIRE MALKOVICH\n INSECTS STONE\n REAR TRADING\n LOATHING LEGALLY\n PACIFIC AMISTAD\n RAGE GAMES\n STEEL SANTA\n BACKLASH UNDEFEATED\n ICE CROSSING\n EYES DRIVING\n SINNERS ATLANTIS\n DALMATIONS SWEDEN\n INCH JET\n LOSE INCH\n SLEUTH ORIENT\n NIGHTMARE CHILL\n GLEAMING JAWBREAKER\n PIRATES ROXANNE\n FANTASY TROOPERS\n SHAWSHANK BUBBLE\n ORIENT CLOSER\n HUSTLER PARTY\n DISCIPLE MOTHER\n BORROWERS BEDAZZLED\n DREAM PICKUP\n APACHE DIVINE\n REIGN GENTLEMEN\n CLEOPATRA DEVIL\n MUSCLE BRIGHT\n WAIT CIDER\n HIGHBALL POTTER\n CUPBOARD SINNERS\n GOODFELLAS SALUTE\n DOORS PRESIDENT\n TRADING PINOCCHIO\n TITANIC BOONDOCK\n STREETCAR INTENTIONS\n BLACKOUT PRIVATE\n STRANGELOVE DESIRE\n MUSKETEERS WAIT\n NETWORK PEAK\n SUNRISE LEAGUE\n AIRPORT POLLOCK\n GORGEOUS BINGO\n IDAHO LOVE\n VACATION BOONDOCK\n HANGING DEEP\n CHAINSAW UPTOWN\n LEBOWSKI SOLDIERS\n FLATLINERS KILLER\n STRANGERS GRAFFITI\n SUN CONFESSIONS\n CAMELOT VACATION\n LIAISONS SWEET\n MISSION ZOOLANDER\n POTTER CONNECTICUT\n ROOTS REMEMBER\n RANGE MOONWALKER\n LOLA AGENT\n DIVIDE MONSTER\n CAPER MOTIONS\n SATISFACTION CONFIDENTIAL\n ENOUGH RAGING\n GRAPES FURY\n CHOCOLAT HARRY\n GILMORE BOILED\n HEAVYWEIGHTS BEAST\n WORKING MICROCOSMOS\n ANNIE IDENTITY\n BILL OTHERS\n LOVE SUICIDES\n BIRDS PERDITION\n REQUIEM TYCOON\n CENTER DINOSAUR\n ARIZONA BANG\n ROUGE SQUAD\n GENTLEMEN STAGE\n SLEEPY JAPANESE\n MIDNIGHT WESTWARD\n FREAKY POCUS\n CONFIDENTIAL INTERVIEW\n ATTRACTION NEWTON\n TIMBERLAND SKY\n CLONES PINOCCHIO\n TRUMAN CRAZY\n WITCHES PANIC\n SWEDEN SHINING\n GROUNDHOG UNCUT\n ...

# %%
res = execute_query("""SELECT
  f.title
FROM film AS f
JOIN inventory AS i
  ON f.film_id = i.film_id
JOIN rental AS r
  ON i.inventory_id = r.inventory_id
GROUP BY
  f.film_id
HAVING
  COUNT(r.rental_id) > (
  SELECT
    AVG(rental_count)
  FROM (
    SELECT
      COUNT(r2.rental_id) AS rental_count
    FROM film AS f2
    JOIN inventory AS i2
      ON f2.film_id = i2.film_id
    JOIN rental AS r2
      ON i2.inventory_id = r2.inventory_id
    GROUP BY
      f2.film_id
  ) AS film_rental_counts
);""".replace("\n"," "))

print(res)
# Out:
#             title
# -----------------------------
#  EFFECT GLADIATOR
#  BALLOON HOMEWARD
#  VOYAGE LEGALLY
#  BIKINI BORROWERS
#  GARDEN ISLAND
#  CONGENIALITY QUEST
#  EXCITEMENT EVE
#  PATIENT SISTER
#  AMISTAD MIDSUMMER
#  EASY GLADIATOR
#  HILLS NEIGHBORS
#  MALTESE HOPE
#  SATURDAY LAMBS
#  OPERATION OPERATION
#  SEATTLE EXPECATIONS
#  SHOW LORD
#  MILLION ACE
#  BASIC EASY
#  AMADEUS HOLY
#  CLUB GRAFFITI
#  OSCAR GOLD
#  DYNAMITE TARZAN
#  FELLOWSHIP AUTUMN
#  GOLDFINGER SENSIBILITY
#  STAR OPERATION
#  BOUND CHEAPER
#  SLACKER LIAISONS
#  FATAL HAUNTED
#  BANGER PINOCCHIO
#  CONTACT ANONYMOUS
#  ROOM ROMAN
#  ALADDIN CALENDAR
#  ARACHNOPHOBIA ROLLERCOASTER
#  DEER VIRGINIAN
#  SOUTH WAIT
#  CONFUSED CANDLES
#  MOONSHINE CABIN
#  ENGLISH BULWORTH
#  HALF OUTFIELD
#  FURY MURDER
#  TRAMP OTHERS
#  ROSES TREASURE
#  LOUISIANA HARRY
#  HOMICIDE PEACH
#  OPEN AFRICAN
#  ROXANNE REBEL
#  DESERT POSEIDON
#  SECRETARY ROUGE
#  COAST RAINBOW
#  UNDEFEATED DALMATIONS
#  KISSING DOLLS
#  MADNESS ATTACKS
#  ALTER VICTORY
#  CHILL LUCK
#  MASSACRE USUAL
#  KICK SAVANNAH
#  BEACH HEARTBREAKERS
#  DETECTIVE VISION
#  PEAK FOREVER
#  SNATCH SLIPPER
#  EXPECATIONS NATURAL
#  STORY SIDE
#  JEKYLL FROGMEN
#  OTHERS SOUP
#  GRIT CLOCKWORK
#  GREATEST NORTH
#  JERICHO MULAN
#  OUTBREAK DIVINE
#  FLAMINGOS CONNECTICUT
#  CAMPUS REMEMBER
#  BRIDE INTRIGUE
#  BEAR GRACELAND
#  CAT CONEHEADS
#  MALLRATS UNITED
#  FORREST SONS
#  SNOWMAN ROLLERCOASTER
#  PHILADELPHIA WIFE
#  SECRETS PARADISE
#  VIRGIN DAISY
#  MAIDEN HOME
#  VIRGINIAN PLUTO
#  BREAKFAST GOLDFINGER
#  VOICE PEACH
#  CONEHEADS SMOOCHY
#  HEARTBREAKERS BRIGHT
#  LIES TREATMENT
#  FLINTSTONES HAPPINESS
#  VANISHING ROCKY
#  WOLVES DESIRE
#  DRACULA CRYSTAL
#  DRIVING POLISH
#  CHARIOTS CONSPIRACY
#  HOBBIT ALIEN
#  WHISPERER GIANT
#  BOULEVARD MOB
#  HURRICANE AFFAIR
#  GUN BONNIE
#  ARMAGEDDON LOST
#  POND SEATTLE
#  LION UNCUT
#  KARATE MOON
#  CANYON STOCK
#  PITY BOUND
#  FIREBALL PHILADELPHIA
#  MURDER ANTITRUST
#  PULP BEVERLY
#  JOON NORTHWEST
#  INSTINCT AIRPORT
#  BRINGING HYSTERICAL
#  JASON TRAP
#  GRAFFITI LOVE
#  GHOST GROUNDHOG
#  OUTFIELD MASSACRE
#  ALASKA PHANTOM
#  JEDI BENEATH
#  CLASH FREDDY
#  PARADISE SABRINA
#  DISTURBING SCARFACE
#  JADE BUNCH
#  RUGRATS SHAKESPEARE
#  EARTH VISION
#  TOURIST PELICAN
#  CANDIDATE PERDITION
#  WESTWARD SEABISCUIT
#  TRIP NEWTON
#  INSIDER ARIZONA
#  JUMPING WRATH
#  ROAD ROXANNE
#  HOURS RAGE
#  WEEKEND PERSONAL
#  SWARM GOLD
#  NOON PAPI
#  DURHAM PANKY
#  SCARFACE BANG
#  STAGECOACH ARMAGEDDON
#  CHRISTMAS MOONSHINE
#  EMPIRE MALKOVICH
#  INSECTS STONE
#  REAR TRADING
#  LOATHING LEGALLY
#  PACIFIC AMISTAD
#  RAGE GAMES
#  STEEL SANTA
#  BACKLASH UNDEFEATED
#  ICE CROSSING
#  EYES DRIVING
#  SINNERS ATLANTIS
#  DALMATIONS SWEDEN
#  INCH JET
#  LOSE INCH
#  SLEUTH ORIENT
#  NIGHTMARE CHILL
#  GLEAMING JAWBREAKER
#  PIRATES ROXANNE
#  FANTASY TROOPERS
#  SHAWSHANK BUBBLE
#  ORIENT CLOSER
#  HUSTLER PARTY
#  DISCIPLE MOTHER
#  BORROWERS BEDAZZLED
#  DREAM PICKUP
#  APACHE DIVINE
#  REIGN GENTLEMEN
#  CLEOPATRA DEVIL
#  MUSCLE BRIGHT
#  WAIT CIDER
#  HIGHBALL POTTER
#  CUPBOARD SINNERS
#  GOODFELLAS SALUTE
#  DOORS PRESIDENT
#  TRADING PINOCCHIO
#  TITANIC BOONDOCK
#  STREETCAR INTENTIONS
#  BLACKOUT PRIVATE
#  STRANGELOVE DESIRE
#  MUSKETEERS WAIT
#  NETWORK PEAK
#  SUNRISE LEAGUE
#  AIRPORT POLLOCK
#  GORGEOUS BINGO
#  IDAHO LOVE
#  VACATION BOONDOCK
#  HANGING DEEP
#  CHAINSAW UPTOWN
#  LEBOWSKI SOLDIERS
#  FLATLINERS KILLER
#  STRANGERS GRAFFITI
#  SUN CONFESSIONS
#  CAMELOT VACATION
#  LIAISONS SWEET
#  MISSION ZOOLANDER
#  POTTER CONNECTICUT
#  ROOTS REMEMBER
#  RANGE MOONWALKER
#  LOLA AGENT
#  DIVIDE MONSTER
#  CAPER MOTIONS
#  SATISFACTION CONFIDENTIAL
#  ENOUGH RAGING
#  GRAPES FURY
#  CHOCOLAT HARRY
#  GILMORE BOILED
#  HEAVYWEIGHTS BEAST
#  WORKING MICROCOSMOS
#  ANNIE IDENTITY
#  BILL OTHERS
#  LOVE SUICIDES
#  BIRDS PERDITION
#  REQUIEM TYCOON
#  CENTER DINOSAUR
#  ARIZONA BANG
#  ROUGE SQUAD
#  GENTLEMEN STAGE
#  SLEEPY JAPANESE
#  MIDNIGHT WESTWARD
#  FREAKY POCUS
#  CONFIDENTIAL INTERVIEW
#  ATTRACTION NEWTON
#  TIMBERLAND SKY
#  CLONES PINOCCHIO
#  TRUMAN CRAZY
#  WITCHES PANIC
#  SWEDEN SHINING
#  GROUNDHOG UNCUT
#  FERRIS MOTHER
#  TELEMARK HEARTBREAKERS
#  FIDELITY DEVIL
#  CHEAPER CLYDE
#  NAME DETECTIVE
#  CROOKED FROGMEN
#  WEDDING APOLLO
#  SAMURAI LION
#  DECEIVER BETRAYED
#  BADMAN DAWN
#  MINE TITANS
#  TROJAN TOMORROW
#  STING PERSONAL
#  VELVET TERMINATOR
#  CORE SUIT
#  RUSH GOODFELLAS
#  MALKOVICH PET
#  HAUNTING PIANIST
#  HOLOCAUST HIGHBALL
#  PELICAN COMFORTS
#  FEUD FROGMEN
#  STORM HAPPINESS
#  ORANGE GRAPES
#  WASH HEAVENLY
#  ENCOUNTERS CURTAIN
#  RIVER OUTLAW
#  EARRING INSTINCT
#  KNOCK WARLOCK
#  CANDLES GRAPES
#  ATLANTIS CAUSE
#  GANGS PRIDE
#  TROUBLE DATE
#  REUNION WITCHES
#  LADY STAGE
#  DOOM DANCING
#  FORWARD TEMPLE
#  PIANIST OUTFIELD
#  AFFAIR PREJUDICE
#  PRINCESS GIANT
#  NOVOCAINE FLIGHT
#  AGENT TRUMAN
#  BOOGIE AMELIE
#  UNBREAKABLE KARATE
#  GO PURPLE
#  DINOSAUR SECRETARY
#  LEAGUE HELLFIGHTERS
#  SWEETHEARTS SUSPECTS
#  GIANT TROOPERS
#  HELLFIGHTERS SIERRA
#  ROBBERS JOON
#  COLOR PHILADELPHIA
#  MOON BUNCH
#  CHICKEN HELLFIGHTERS
#  UNFORGIVEN ZOOLANDER
#  HEAVEN FREEDOM
#  PACKER MADIGAN
#  CROSSROADS CASUALTIES
#  RIDGEMONT SUBMARINE
#  RACER EGG
#  RESURRECTION SILVERADO
#  WONDERLAND CHRISTMAS
#  SLUMS DUCK
#  NEWTON LABYRINTH
#  MARRIED GO
#  FARGO GANDHI
#  FROST HEAD
#  IDOLS SNATCHERS
#  BROTHERHOOD BLANKET
#  JACKET FRISCO
#  BEVERLY OUTLAW
#  TEEN APOLLO
#  HIGH ENCINO
#  WIND PHANTOM
#  PINOCCHIO SIMON
#  HEAD STRANGER
#  SHAKESPEARE SADDLE
#  POLLOCK DELIVERANCE
#  WOMEN DORADO
#  ALAMO VIDEOTAPE
#  MIDSUMMER GROUNDHOG
#  ROMAN PUNK
#  TORQUE BOUND
#  INDEPENDENCE HOTEL
#  ENCINO ELF
#  POCUS PULP
#  FANTASIA PARK
#  AMERICAN CIRCUS
#  ESCAPE METROPOLIS
#  HANOVER GALAXY
#  GUNFIGHT MOON
#  BAREFOOT MANCHURIAN
#  DOUBLE WRATH
#  BERETS AGENT
#  TOMORROW HUSTLER
#  JERK PAYCHECK
#  FREDDY STORM
#  ISLAND EXORCIST
#  INTENTIONS EMPIRE
#  COMA HEAD
#  FALCON VOLUME
#  ENEMY ODDS
#  GOLDMINE TYCOON
#  DANCING FEVER
#  HUNCHBACK IMPOSSIBLE
#  MOCKINGBIRD HOLLYWOOD
#  METROPOLIS COMA
#  FRENCH HOLIDAY
#  EGYPT TENENBAUMS
#  DOWNHILL ENOUGH
#  CHASING FIGHT
#  SUSPECTS QUILLS
#  SUNDANCE INVASION
#  PERFECT GROOVE
#  HARRY IDAHO
#  NORTHWEST POLISH
#  GREEK EVERYONE
#  DAWN POND
#  CELEBRITY HORN
#  ANACONDA CONFESSIONS
#  JET NEIGHBORS
#  NONE SPIKING
#  MAJESTIC FLOATS
#  THIEF PELICAN
#  FIGHT JAWBREAKER
#  HORN WORKING
#  TAXI KICK
#  FACTORY DRAGON
#  COMFORTS RUSH
#  GABLES METROPOLIS
#  WHALE BIKINI
#  HOUSE DYNAMITE
#  VIDEOTAPE ARSENIC
#  VOLCANO TEXAS
#  CHANCE RESURRECTION
#  ZOOLANDER FICTION
#  QUEST MUSSOLINI
#  PATTON INTERVIEW
#  SALUTE APOLLO
#  TELEGRAPH VOYAGE
#  DETAILS PACKER
#  KISS GLORY
#  FICTION CHRISTMAS
#  BINGO TALENTED
#  BUCKET BROTHERHOOD
#  TALENTED HOMICIDE
#  CAROL TEXAS
#  DOGMA FAMILY
#  MASK PEACH
#  STEPMOM DREAM
#  SABRINA MIDNIGHT
#  ALIEN CENTER
#  SUGAR WONKA
#  SCALAWAG DUCK
#  BEAUTY GREASE
#  DORADO NOTTING
#  MOURNING PURPLE
#  POSEIDON FOREVER
#  INVASION CYCLONE
#  PRIMARY GLASS
#  DRAGONFLY STRANGERS
#  HANKY OCTOBER
#  SHEPHERD MIDSUMMER
#  MASKED BUBBLE
#  HARPER DYING
#  SLEEPING SUSPECTS
#  HYDE DOCTOR
#  INTRIGUE WORST
#  SECRET GROUNDHOG
#  FOOL MOCKINGBIRD
#  DRIFTER COMMANDMENTS
#  BUTTERFLY CHOCOLAT
#  REMEMBER DIARY
#  SEA VIRGIN
#  MOVIE SHAKESPEARE
#  GROOVE FICTION
#  FAMILY SWEET
#  SCORPION APOLLO
#  SPICE SORORITY
#  DRIVER ANNIE
#  GREASE YOUTH
#  CLOSER BANG
#  HOPE TOOTSIE
#  WONKA SEA
#  STRICTLY SCARFACE
#  NEIGHBORS CHARADE
#  TIGHTS DAWN
#  FISH OPUS
#  ACADEMY DINOSAUR
#  CAUSE DATE
#  SHOCK CABIN
#  GALAXY SWEETHEARTS
#  EAGLES PANKY
#  SEABISCUIT PUNK
#  SUIT WALLS
#  CLUELESS BUCKET
#  ROCKETEER MOTHER
#  FORRESTER COMANCHEROS
#  IGBY MAKER
#  GANDHI KWAI
#  KWAI HOMEWARD
#  CALENDAR GUNFIGHT
#  MARS ROMAN
#  SOMETHING DUCK
#  ROCK INSTINCT
#  CURTAIN VIDEOTAPE
#  WATERFRONT DELIVERANCE
#  MONEY HAROLD
#  WIFE TURN
#  BLADE POLISH
#  MUSIC BOONDOCK
#  SMOKING BARBARELLA
#  MINDS TRUMAN
#  LAWLESS VISION
#  ALONE TRIP
#  DARN FORRESTER
#  REDEMPTION COMFORTS
#  JUGGLER HARDLY
#  ZORRO ARK
#  NATIONAL STORY
#  QUEEN LUKE
#  BLUES INSTINCT
#  METAL ARMAGEDDON
#  HANDICAP BOONDOCK
#  WARDROBE PHANTOM
#  EXPENDABLE STALLION
#  PREJUDICE OLEANDER
#  EGG IGBY
#  SPLENDOR PATTON
#  POLISH BROOKLYN
#  INNOCENT USUAL
#  DYING MAKER
#  STRAIGHT HOURS
#  TITANS JERK
#  WRONG BEHAVIOR
#  FLYING HOOK
#  SLEEPLESS MONSOON
#  OZ LIAISONS
#  CONVERSATION DOWNHILL
#  BROOKLYN DESERT
#  UNITED PILOT
#  CIDER DESIRE
#  HONEY TIES
#  SPY MILE
#  ANGELS LIFE
#  CARRIE BUNCH
#  HORROR REIGN
#  YENTL IDAHO
#  TRACY CIDER
#  INTERVIEW LIAISONS
#  BARBARELLA STREETCAR
#  SHOOTIST SUPERFLY
# (475 rows)

# %% [markdown]
# ## Loading the Evaluation Dataset

# %%
import pandas as pd

file_path = r".\Pagila Evals Dataset(Sheet1).csv"

# Read CSV with an alternate encoding
test_queries = pd.read_csv(file_path, encoding="ISO-8859-1")  # or encoding="latin1"
print(test_queries.head())
# Out:
#    Query Number                             Natural Language Query Difficulty
# 0             1             List all actors' first and last names.       Easy
# 1             2      Show the titles of all films in the database.       Easy
# 2             3                       Get the names of all cities.       Easy
# 3             4           List all categories available for films.       Easy
# 4             5  Show the first name and last name of all custo...       Easy

# %%
test_queries.head()
# Out:
#    Query Number                             Natural Language Query Difficulty
# 0             1             List all actors' first and last names.       Easy
# 1             2      Show the titles of all films in the database.       Easy
# 2             3                       Get the names of all cities.       Easy
# 3             4           List all categories available for films.       Easy
# 4             5  Show the first name and last name of all custo...       Easy

# %% [markdown]
# ## Inferencing the agent

# %%
# Ensure columns exist before iteration

if "sql_gen_query" not in test_queries.columns:
    test_queries["sql_gen_query"] = np.nan

if "results" not in test_queries.columns:
    test_queries["results"] = np.nan

# Iterate over DataFrame with progress bar
for index, row in tqdm(test_queries.iterrows(), total=len(test_queries), desc="Processing Queries"):
    if pd.isna(row["sql_gen_query"]) or (isinstance(row["sql_gen_query"], str) and "(0 rows)" in row["sql_gen_query"]) or (pd.notna(row["results"]) and isinstance(row["results"], str) and "ERROR" in row["results"]):
        sql, output = process_query(row["Natural Language Query"])
        # print(output, "\n\n\n")

        # Update the DataFrame in place
        test_queries.at[index, "sql_gen_query"] = sql
        test_queries.at[index, "results"] = output
        
        if index%5 == 0:
            print(f"Sleeping for 5 seconds at index {index}") # Scleeping to 
            time.sleep(5)
            

# Save to CSV after updating all rows
test_queries.to_csv("inference_results.csv", index=False)
# Out:
# Processing Queries:  70%|███████   | 28/40 [00:02<00:01, 11.29it/s]
# Error running query: ERROR:  function date(unknown, unknown) does not exist
# LINE 1: SELECT * FROM customer WHERE create_date >= date('now', '-6 ...
#                                                     ^
# HINT:  No function matches the given name and argument types. You might need to add explicit type casts.
#
# Error running query: ERROR:  function date(unknown, unknown) does not exist
# LINE 1: SELECT * FROM customer WHERE create_date >= DATE('now', '-6 ...
#                                                     ^
# HINT:  No function matches the given name and argument types. You might need to add explicit type casts.
#
# Error running query: ERROR:  column "create_date" does not exist
# LINE 1: SELECT * FROM staff WHERE create_date < '2020-01-01'
#                                   ^
# Processing Queries:  75%|███████▌  | 30/40 [00:13<00:05,  1.76it/s]
# Sleeping for 5 seconds at index 30
# Processing Queries:  78%|███████▊  | 31/40 [00:21<00:09,  1.08s/it]
# Error running query: ERROR:  column rental.id does not exist
# LINE 1: ...film_id JOIN rental   ON inventory.inventory_id = rental.id ...
#                                                              ^
# Processing Queries:  88%|████████▊ | 35/40 [00:35<00:09,  1.81s/it]
# Sleeping for 5 seconds at index 35
# Processing Queries: 100%|██████████| 40/40 [00:56<00:00,  1.42s/it]

# %%
error_rows = test_queries[test_queries["results"].astype(str).str.contains(r"Error", case=False, na=False)]

# %%
error_rows
# Out:
# Empty DataFrame
# Columns: [Query Number, Natural Language Query, Difficulty, sql_gen_query, results]
# Index: []

# %% [markdown]
# ### Since we can see that there are no error_rows, we can consider that the errors in sql syntax is resolved by reattempts by the process_query()

# %%
for index, row in error_rows.iterrows():
    print(f"Natural Language Query:\n{row['Natural Language Query']}\n")
    print(f"sql_gen_query:\n{row['sql_gen_query']}\n")
    print(f"results: {row['results']}\n")

# %% [markdown]
# ## Checking the inferenced results

# %%
import pandas as pd

file_path = r".\inferenced_results.csv"

# Read CSV with an alternate encoding
inferenced_df = pd.read_csv(file_path, encoding="ISO-8859-1")  # or encoding="latin1"
print(inferenced_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Query Number            40 non-null     int64
#  1   Natural Language Query  40 non-null     object
#  2   Difficulty              40 non-null     object
#  3   Query                   40 non-null     object
#  4   sql_gen_query           40 non-null     object
#  5   results                 40 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.0+ KB
# None

# %%
inferenced_df.head()
# Out:
#    Query Number                             Natural Language Query Difficulty  \
# 0             1             List all actors' first and last names.       Easy
# 1             2      Show the titles of all films in the database.       Easy
# 2             3                       Get the names of all cities.       Easy
# 3             4           List all categories available for films.       Easy
# 4             5  Show the first name and last name of all custo...       Easy
#
#                                                Query  \
# 0             List all actors' first and last names.
# 1      Show the titles of all films in the database.
# 2                       Get the names of all cities.
# 3           List all categories available for films.
# 4  Show the first name and last name of all custo...
#
#                                  sql_gen_query  \
# 0     SELECT first_name, last_name FROM actor;
# 1                      SELECT title FROM film;
# 2                       SELECT city FROM city;
# 3                   SELECT name FROM category;
# 4  SELECT first_name, last_name FROM customer;
#
#                                              results
# 0   first_name  |  last_name   \n-------------+--...
# 1              title            \n---------------...
# 2              city            \n----------------...
# 3      name     \n-------------\n Action\n Animat...
# 4   first_name  |  last_name   \n-------------+--...

# %% [markdown]
# ## Checking the inferenced results with `0 rows` output

# %%
check = inferenced_df.loc[28,"results"]

print(check)
# Out:
#  customer_id | store_id | first_name | last_name | email | address_id | activebool | create_date | last_update | active
# -------------+----------+------------+-----------+-------+------------+------------+-------------+-------------+--------
# (0 rows)

# %%
filtered_df = inferenced_df[inferenced_df["results"].str.contains(r"\(0 rows\)", regex=True, na=False)]
filtered_df
# Out:
#     Query Number                             Natural Language Query  \
# 6              7        Find all actors with the last name "Smith."
# 7              8  List all customers who are from the city of Â...
# 16            17  Show all actors who appeared in the film "Ince...
# 19            20      Find all films rented by customer "John Doe."
# 25            26          Show all rentals made in the last 7 days.
# 28            29  Find all customers who registered in the last ...
# 31            32  Find the films that have been rented more time...
# 35            36  Find customers who have rented more films this...
# 37            38  For each customer, show the number of films re...
# 38            39  Show the names of customers who have rented ev...
# 39            40  List customers who have rented the same film m...
#
#    Difficulty                                              Query  \
# 6        Easy        Find all actors with the last name "Smith."
# 7        Easy  List all customers who are from the city of Â...
# 16     Medium  Show all actors who appeared in the film "Ince...
# 19     Medium      Find all films rented by customer "John Doe."
# 25     Medium          Show all rentals made in the last 7 days.
# 28     Medium  Find all customers who registered in the last ...
# 31       Hard  Find the films that have been rented more time...
# 35       Hard  Find customers who have rented more films this...
# 37       Hard  For each customer, show the number of films re...
# 38       Hard  Show the names of customers who have rented ev...
# 39       Hard  List customers who have rented the same film m...
#
#                                         sql_gen_query  \
# 6   SELECT actor_id, first_name, last_name\nFROM a...
# 7   SELECT\n  C.first_name,\n  C.last_name\nFROM C...
# 16  SELECT A.first_name, A.last_name\nFROM actor A...
# 19  SELECT F.title\nFROM film AS F\nJOIN inventory...
# 25  SELECT *\nFROM rental\nWHERE rental_date >= NO...
# 28  SELECT * FROM customer WHERE create_date >= DA...
# 31  SELECT film_id\nFROM inventory\nGROUP BY film_...
# 35  SELECT c.first_name, c.last_name\nFROM custome...
# 37  WITH MonthlyRentals AS (\n    SELECT\n        ...
# 38  SELECT c.first_name, c.last_name\nFROM custome...
# 39  SELECT c.first_name, c.last_name, f.title, COU...
#
#                                               results
# 6    actor_id | first_name | last_name \n---------...
# 7    first_name | last_name \n------------+-------...
# 16   first_name | last_name \n------------+-------...
# 19                      title \n-------\n(0 rows)\n\n
# 25   rental_id | rental_date | inventory_id | cust...
# 28   customer_id | store_id | first_name | last_na...
# 31                  film_id \n---------\n(0 rows)\n\n
# 35   first_name | last_name \n------------+-------...
# 37   customer_id | rental_month | rental_count | p...
# 38   first_name | last_name \n------------+-------...
# 39   first_name | last_name | title | rental_count...

# %% [markdown]
# ### Manually checking the 0 rows results - Looks like the SQL query is correct

# %%
idx=7

# query = filtered_df.iloc[idx]["Query"]
query = "Find customers who have rented less films this year than last yea"
sql_query = filtered_df.iloc[idx]["sql_gen_query"]
print("Query:", query)
print("SQL:", sql_query, "\n\n\n")


result = execute_query(sql_query.replace("\n", " "))
print(result)
# Out:
# Query: Find customers who have rented less films this year than last yea
# SQL: SELECT c.first_name, c.last_name
# FROM customer c
# JOIN rental r ON c.customer_id = r.customer_id
# WHERE EXTRACT(YEAR FROM r.rental_date) = EXTRACT(YEAR FROM CURRENT_DATE)
# GROUP BY c.customer_id, c.first_name, c.last_name
# HAVING COUNT(DISTINCT r.rental_id) > (
#     SELECT COUNT(DISTINCT r2.rental_id)
#     FROM rental r2
#     WHERE r2.customer_id = c.customer_id
#       AND EXTRACT(YEAR FROM r2.rental_date) = EXTRACT(YEAR FROM CURRENT_DATE) - 1
# );
#
#
#
#  first_name | last_name
# ------------+-----------
# (0 rows)

# %% [markdown]
# #### Query to sort by rental_date in descending order and limit the result to the top 5 using ORDER BY and LIMIT.

# %%
result = execute_query("""
    SELECT c.first_name, c.last_name, r.rental_date
    FROM customer c
    JOIN rental r ON c.customer_id = r.customer_id
    ORDER BY r.rental_date DESC
    LIMIT 5;
""".replace("\n", " "))

print(result)
# Out:
#  first_name | last_name |      rental_date
# ------------+-----------+------------------------
#  PHILIP     | CAUSEY    | 2022-08-23 21:50:12+00
#  GLADYS     | HAMILTON  | 2022-08-23 21:43:07+00
#  GRACE      | ELLIS     | 2022-08-23 21:42:48+00
#  DENISE     | KELLY     | 2022-08-23 21:26:47+00
#  BETTY      | WHITE     | 2022-08-23 21:25:26+00
# (5 rows)

# %% [markdown]
# #### Last date is `2022-08-23 21:50:12+00`, so the prospect of choosing records from this year - 2025 and previous year - 2024 will always give us 0 rows, with this dataset

# %% [markdown]
# ## LLM Judge - SQL Evaluation

# %%
def judge_sql_logic(nl_query: str, sql_query: str,DATABASE_SCHEMA=DATABASE_SCHEMA) -> str:
    """
    Uses Gemini to verify if the given SQL query correctly implements the natural language query logic.
    
    Args:
        nl_query (str): The natural language query.
        sql_query (str): The SQL query to check.
    
    Returns:
        str: A response indicating if the SQL query is logically correct, with reasoning.
    """
    agent = ChatGoogleGenerativeAI(model="gemini-pro")
    prompt = f""" 
        Check if the following SQL query correctly implements the given natural language request:

        NL Query: {nl_query}
        SQL Query: {sql_query}
        
        Provided Database Schema: 
        {DATABASE_SCHEMA}

        Provide a response indicating if it is logically correct, with reasoning.
        The scoring breakdown could be as follows:
        100 for fully correct queries.
        50 for queries that are logically correct but have minor errors.
        0 for queries that are incorrect or produce the wrong results
        
        The response should be in the following format:
        Score: 100
        Reasoning: The query is fully correct.
        Score: 50
        Reasoning: The query is logically correct but has minor errors. (with proper reasoning and improvements)
        Score: 0
        Reasoning: The query is incorrect or produces the wrong results. (with proper reasoning and improvements)

    """
            
    response = agent([HumanMessage(content=prompt)])
    
    response_lines = response.content.strip().split("\n")
    # print(response.content)
    score = (
        response_lines[0]
        .replace("Score: ", "")
        .strip("\"'")
    )
    reasoning = (
        response_lines[1].replace("Reasoning: ", "").strip("\"'")
        if len(response_lines) > 1
        else ""
    )
    return {
        "score": int(score),
        "reasoning": reasoning,
    }

# %%
idx=7

query = inferenced_df.iloc[idx]["Query"]
sql_query = inferenced_df.iloc[idx]["sql_gen_query"]
print("Query:", query)
print("SQL:", sql_query, "\n\n\n")


response = judge_sql_logic([query],[sql_query])

score = response["score"]
reasoning = response["reasoning"]

print("Score:", score)
print("Reasoning:", reasoning)
# Out:
# Query: List all customers who are from the city of ÂNew York.Â
# SQL: SELECT
#   C.first_name,
#   C.last_name
# FROM Customer AS C
# JOIN Address AS A
#   ON C.address_id = A.address_id
# JOIN City AS CI
#   ON A.city_id = CI.city_id
# WHERE
#   CI.city = 'New York';
#
#
#
# Score: 100
# Reasoning: The SQL query is fully correct. It performs a join between the Customer, Address, and City tables to retrieve the first name and last name of customers who are from the city of New York. The query uses the city_id column to link the Address table to the City table and the address_id column to link the Customer table to the Address table. The WHERE clause filters the results to include only customers who are from the city of New York.

# %%
# Ensure columns exist before iteration
if "reasoning" not in inferenced_df.columns:
    inferenced_df["reasoning"] = np.nan

if "score" not in inferenced_df.columns:
    inferenced_df["score"] = np.nan

# Iterate over the DataFrame with progress bar
for index, row in tqdm(inferenced_df.iterrows(), total=len(inferenced_df), desc="Evaluating SQL Queries"):
    if pd.isna(row["reasoning"]) or pd.isna(row["score"]):
        query = row["Query"]
        sql_query = row["sql_gen_query"]

        response = judge_sql_logic(query, sql_query)

        score = response["score"]
        reasoning = response["reasoning"]

        # Update the DataFrame in place
        inferenced_df.at[index, "score"] = score
        inferenced_df.at[index, "reasoning"] = reasoning
        
        if index%5 == 0:
            print(f"Sleeping for 5 seconds at index {index}") # Scleeping to 
            time.sleep(5)

# Save to CSV after updating all rows
inferenced_df.to_csv("evaluation_results.csv", index=False)
# Out:
# Evaluating SQL Queries:  12%|█▎        | 5/40 [00:12<01:33,  2.68s/it]
# Sleeping for 5 seconds at index 5
# Evaluating SQL Queries:  25%|██▌       | 10/40 [00:30<01:29,  2.98s/it]
# Sleeping for 5 seconds at index 10
# Evaluating SQL Queries:  38%|███▊      | 15/40 [00:51<01:27,  3.50s/it]
# Sleeping for 5 seconds at index 15
# Evaluating SQL Queries:  50%|█████     | 20/40 [01:10<01:02,  3.12s/it]
# Sleeping for 5 seconds at index 20
# Evaluating SQL Queries:  62%|██████▎   | 25/40 [01:31<00:55,  3.71s/it]
# Sleeping for 5 seconds at index 25
# Evaluating SQL Queries:  75%|███████▌  | 30/40 [01:51<00:36,  3.61s/it]
# Sleeping for 5 seconds at index 30
# Evaluating SQL Queries:  88%|████████▊ | 35/40 [02:12<00:17,  3.57s/it]
# Sleeping for 5 seconds at index 35
# Evaluating SQL Queries: 100%|██████████| 40/40 [02:33<00:00,  3.83s/it]

# %%
inferenced_df.head()
# Out:
#    Query Number                             Natural Language Query Difficulty  \
# 0             1             List all actors' first and last names.       Easy
# 1             2      Show the titles of all films in the database.       Easy
# 2             3                       Get the names of all cities.       Easy
# 3             4           List all categories available for films.       Easy
# 4             5  Show the first name and last name of all custo...       Easy
#
#                                                Query  \
# 0             List all actors' first and last names.
# 1      Show the titles of all films in the database.
# 2                       Get the names of all cities.
# 3           List all categories available for films.
# 4  Show the first name and last name of all custo...
#
#                                  sql_gen_query  \
# 0     SELECT first_name, last_name FROM actor;
# 1                      SELECT title FROM film;
# 2                       SELECT city FROM city;
# 3                   SELECT name FROM category;
# 4  SELECT first_name, last_name FROM customer;
#
#                                              results  \
# 0   first_name  |  last_name   \n-------------+--...
# 1              title            \n---------------...
# 2              city            \n----------------...
# 3      name     \n-------------\n Action\n Animat...
# 4   first_name  |  last_name   \n-------------+--...
#
#                                            reasoning  score
# 0  The query is fully correct. It retrieves the f...  100.0
# 1  The query is fully correct. It selects the tit...  100.0
# 2  The query is fully correct. It retrieves the c...  100.0
# 3  The query is fully correct. It selects the nam...  100.0
# 4  The query is fully correct. It selects the fir...  100.0

# %% [markdown]
# ## Check evaluated results

# %%
import pandas as pd

file_path = r".\evaluation_results.csv"

# Read CSV with an alternate encoding
evaluated_df = pd.read_csv(file_path, encoding="ISO-8859-1")  # or encoding="latin1"
print(evaluated_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Query Number            40 non-null     int64
#  1   Natural Language Query  40 non-null     object
#  2   Difficulty              40 non-null     object
#  3   Query                   40 non-null     object
#  4   sql_gen_query           40 non-null     object
#  5   results                 40 non-null     object
#  6   reasoning               40 non-null     object
#  7   score                   40 non-null     float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.6+ KB
# None

# %%
evaluated_df
# Out:
#     Query Number                             Natural Language Query  \
# 0              1             List all actors' first and last names.
# 1              2      Show the titles of all films in the database.
# 2              3                       Get the names of all cities.
# 3              4           List all categories available for films.
# 4              5  Show the first name and last name of all custo...
# 5              6                   Show all films released in 2006.
# 6              7        Find all actors with the last name "Smith."
# 7              8  List all customers who are from the city of Ã...
# 8              9  Get all stores located in the country ÃÂIndi...
# 9             10  Show all films with a rental rate greater than...
# 10            11         How many films are there in each category?
# 11            12                What is the total number of actors?
# 12            13       Get the total payment received in June 2022.
# 13            14  Find the total number of rentals made last month.
# 14            15     How many films have a rating of ÃÂPG-13ÃÂ?
# 15            16    List all films along with their category names.
# 16            17  Show all actors who appeared in the film "Ince...
# 17            18  Get a list of all customers and the films they...
# 18            19  List all staff members along with the stores t...
# 19            20      Find all films rented by customer "John Doe."
# 20            21  Show the top 5 films rented the most across al...
# 21            22  List all customers who have rented films in bo...
# 22            23  Find all actors who have appeared in more than...
# 23            24  Get a list of customers who have made more tha...
# 24            25  List all films that are in both the "Action" a...
# 25            26          Show all rentals made in the last 7 days.
# 26            27            Get all payments made in February 2022.
# 27            28  List all films that have not been rented in th...
# 28            29  Find all customers who registered in the last ...
# 29            30  Show all staff members hired before January 1,...
# 30            31  List the top 3 customers who have spent the mo...
# 31            32  Find the films that have been rented more time...
# 32            33  For each actor, show their name and the percen...
# 33            34  Show the average payment amount for each custo...
# 34            35  List all actors who have appeared in at least ...
# 35            36  Find customers who have rented more films this...
# 36            37     List the top 5 films with the highest revenue.
# 37            38  For each customer, show the number of films re...
# 38            39  Show the names of customers who have rented ev...
# 39            40  List customers who have rented the same film m...
#
#    Difficulty                                              Query  \
# 0        Easy             List all actors' first and last names.
# 1        Easy      Show the titles of all films in the database.
# 2        Easy                       Get the names of all cities.
# 3        Easy           List all categories available for films.
# 4        Easy  Show the first name and last name of all custo...
# 5        Easy                   Show all films released in 2006.
# 6        Easy        Find all actors with the last name "Smith."
# 7        Easy  List all customers who are from the city of Ã...
# 8        Easy  Get all stores located in the country ÃÂIndi...
# 9        Easy  Show all films with a rental rate greater than...
# 10     Medium         How many films are there in each category?
# 11     Medium                What is the total number of actors?
# 12     Medium       Get the total payment received in June 2022.
# 13     Medium  Find the total number of rentals made last month.
# 14     Medium     How many films have a rating of ÃÂPG-13ÃÂ?
# 15     Medium    List all films along with their category names.
# 16     Medium  Show all actors who appeared in the film "Ince...
# 17     Medium  Get a list of all customers and the films they...
# 18     Medium  List all staff members along with the stores t...
# 19     Medium      Find all films rented by customer "John Doe."
# 20     Medium  Show the top 5 films rented the most across al...
# 21     Medium  List all customers who have rented films in bo...
# 22     Medium  Find all actors who have appeared in more than...
# 23     Medium  Get a list of customers who have made more tha...
# 24     Medium  List all films that are in both the "Action" a...
# 25     Medium          Show all rentals made in the last 7 days.
# 26     Medium            Get all payments made in February 2022.
# 27     Medium  List all films that have not been rented in th...
# 28     Medium  Find all customers who registered in the last ...
# 29     Medium  Show all staff members hired before January 1,...
# 30       Hard  List the top 3 customers who have spent the mo...
# 31       Hard  Find the films that have been rented more time...
# 32       Hard  For each actor, show their name and the percen...
# 33       Hard  Show the average payment amount for each custo...
# 34       Hard  List all actors who have appeared in at least ...
# 35       Hard  Find customers who have rented more films this...
# 36       Hard     List the top 5 films with the highest revenue.
# 37       Hard  For each customer, show the number of films re...
# 38       Hard  Show the names of customers who have rented ev...
# 39       Hard  List customers who have rented the same film m...
#
#                                         sql_gen_query  \
# 0            SELECT first_name, last_name FROM actor;
# 1                             SELECT title FROM film;
# 2                              SELECT city FROM city;
# 3                          SELECT name FROM category;
# 4         SELECT first_name, last_name FROM customer;
# 5       SELECT * FROM film WHERE release_year = 2006;
# 6   SELECT actor_id, first_name, last_name\nFROM a...
# 7   SELECT\n  C.first_name,\n  C.last_name\nFROM C...
# 8   SELECT S.store_id\nFROM store AS S\nJOIN addre...
# 9   SELECT film_id, title, rental_rate FROM film W...
# 10  SELECT c.name, COUNT(fc.film_id) AS film_count...
# 11                 SELECT COUNT(actor_id) FROM actor;
# 12  SELECT SUM(amount)\nFROM payment\nWHERE paymen...
# 13  SELECT\n  COUNT(rental_id)\nFROM rental\nWHERE...
# 14  SELECT COUNT(film_id) FROM film WHERE rating =...
# 15  SELECT F.title, C.name\nFROM film AS F\nJOIN f...
# 16  SELECT A.first_name, A.last_name\nFROM actor A...
# 17  SELECT\n  C.first_name,\n  C.last_name,\n  F.t...
# 18  SELECT staff.first_name, staff.last_name, stor...
# 19  SELECT F.title\nFROM film AS F\nJOIN inventory...
# 20  SELECT\n  f.title,\n  COUNT(r.rental_id) AS re...
# 21  SELECT c.first_name, c.last_name\nFROM custome...
# 22  SELECT A.first_name, A.last_name\nFROM actor A...
# 23  SELECT customer_id\nFROM payment\nGROUP BY cus...
# 24  SELECT f.title\nFROM film AS f\nJOIN film_cate...
# 25  SELECT *\nFROM rental\nWHERE rental_date >= NO...
# 26  SELECT *\nFROM payment\nWHERE EXTRACT(MONTH FR...
# 27  SELECT\n  f.title\nFROM film AS f\nLEFT JOIN i...
# 28  SELECT * FROM customer WHERE create_date >= DA...
# 29  SELECT * FROM staff WHERE create_date < '2020-...
# 30  WITH CustomerSpending AS (\n    SELECT\n      ...
# 31  SELECT film_id\nFROM inventory\nGROUP BY film_...
# 32  SELECT\n  A.first_name,\n  A.last_name,\n  CAS...
# 33  SELECT c.customer_id, AVG(p.amount) AS average...
# 34  SELECT a.first_name, a.last_name\nFROM actor a...
# 35  SELECT c.first_name, c.last_name\nFROM custome...
# 36  SELECT\n  F.title,\n  SUM(P.amount) AS total_r...
# 37  WITH MonthlyRentals AS (\n    SELECT\n        ...
# 38  SELECT c.first_name, c.last_name\nFROM custome...
# 39  SELECT c.first_name, c.last_name, f.title, COU...
#
#                                               results  \
# 0    first_name  |  last_name   \n-------------+--...
# 1               title            \n---------------...
# 2               city            \n----------------...
# 3       name     \n-------------\n Action\n Animat...
# 4    first_name  |  last_name   \n-------------+--...
# 5    film_id |          title          |          ...
# 6    actor_id | first_name | last_name \n---------...
# 7    first_name | last_name \n------------+-------...
# 8    store_id \n----------\n       13\n       18\n...
# 9    film_id |           title           | rental_...
# 10      name     | film_count \n-------------+----...
# 11               count \n-------\n   200\n(1 row)\n\n
# 12        sum    \n----------\n 10923.45\n(1 row)\n\n
# 13               count \n-------\n     0\n(1 row)\n\n
# 14               count \n-------\n   223\n(1 row)\n\n
# 15              title            |    name     \n-...
# 16   first_name | last_name \n------------+-------...
# 17   first_name  |  last_name   |            title...
# 18   first_name  |   last_name   | store_id \n----...
# 19                      title \n-------\n(0 rows)\n\n
# 20          title        | rental_count \n--------...
# 21   first_name  |  last_name   \n-------------+--...
# 22   first_name  |  last_name   \n-------------+--...
# 23   customer_id \n-------------\n         184\n  ...
# 24         title        \n--------------------\n A...
# 25   rental_id | rental_date | inventory_id | cust...
# 26   payment_id | customer_id | staff_id | rental_...
# 27              title            \n---------------...
# 28   customer_id | store_id | first_name | last_na...
# 29  ERROR:  column "create_date" does not exist\nL...
# 30   customer_id |                country         ...
# 31                  film_id \n---------\n(0 rows)\n\n
# 32   first_name  |  last_name   | percentage_of_fi...
# 33   customer_id | average_payment_amount \n------...
# 34   first_name  |  last_name   \n-------------+--...
# 35   first_name | last_name \n------------+-------...
# 36         title       | total_revenue \n---------...
# 37   customer_id | rental_month | rental_count | p...
# 38   first_name | last_name \n------------+-------...
# 39   first_name | last_name | title | rental_count...
#
#                                             reasoning  score
# 0   The query is fully correct. It retrieves the f...  100.0
# 1   The query is fully correct. It selects the tit...  100.0
# 2   The query is fully correct. It retrieves the c...  100.0
# 3   The query is fully correct. It selects the nam...  100.0
# 4   The query is fully correct. It selects the fir...  100.0
# 5   The query is fully correct. It selects all row...  100.0
# 6   The SQL query is fully correct. It retrieves a...  100.0
# 7   The query is fully correct. It identifies the ...  100.0
# 8   The query is fully correct. It retrieves the s...  100.0
# 9   The query is fully correct. It selects all fil...  100.0
# 10  The query is fully correct. It joins the categ...  100.0
# 11  The query is fully correct. It correctly count...  100.0
# 12  The query is logically correct. It uses the pa...  100.0
# 13  The query is fully correct. It uses the DATE_T...  100.0
# 14  The query is fully correct. It correctly ident...  100.0
# 15  The SQL query correctly implements the given n...  100.0
# 16  The query is fully correct. It uses a JOIN bet...  100.0
# 17  The query is logically correct. It uses JOINs ...  100.0
# 18  The SQL query correctly implements the given n...  100.0
# 19  The query is fully correct. It correctly joins...  100.0
# 20  The query is fully correct. It performs a join...  100.0
# 21  The query is fully correct. It uses the INTERS...  100.0
# 22  The query is fully correct. It uses a JOIN bet...  100.0
# 23  The query is fully correct. It correctly imple...  100.0
# 24  The query is fully correct. It joins the film ...  100.0
# 25  The query is fully correct. It selects all ren...  100.0
# 26  The query is fully correct. It uses the EXTRAC...  100.0
# 27  The query is fully correct. It uses a left joi...  100.0
# 28  The query correctly retrieves all customers wh...  100.0
# 29  The SQL query correctly implements the given n...  100.0
# 30  The query is fully correct. It uses a Common T...  100.0
# 31                        The query is fully correct.  100.0
# 32  The query is fully correct. It uses a self-joi...  100.0
# 33  The query is fully correct. It joins the custo...  100.0
# 34  The query is fully correct. It uses a GROUP BY...  100.0
# 35  The query is fully correct. It correctly imple...  100.0
# 36  The query is fully correct. It joins the neces...  100.0
# 37  The query is fully correct. It uses a common t...  100.0
# 38                        The query is fully correct.  100.0
# 39  The query is fully correct. It correctly ident...  100.0

# %%
mean_score = evaluated_df["score"].mean()

print(f"Mean Score of SQL Evaluation:\n\n{mean_score}")
# Out:
# Mean Score of SQL Evaluation:
#
# 100.0

# %%
# Filter rows where the score is not 100
filtered_df = evaluated_df[evaluated_df["score"] != 100]

# Display the filtered DataFrame
filtered_df
# Out:
# Empty DataFrame
# Columns: [Query Number, Natural Language Query, Difficulty, Query, sql_gen_query, results, reasoning, score]
# Index: []

# %%
for index, row in filtered_df.iterrows():
    print(f"Query: {row['Query']}\n")
    print(f"SQL Generated:\n{row['sql_gen_query']}\n")
    print(f"Reasoning:\n{row['reasoning']}\n")
    print("=" * 80)  # Separator for readability
